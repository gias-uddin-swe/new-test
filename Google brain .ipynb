# %%
# importing important library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import klib
import warnings
warnings.filterwarnings('ignore')

# %%
# Read data files

# %%
df = pd.read_csv('test.csv')

# %%
df_train= pd.read_csv('train.csv')
df_train.head()
# Out:
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %%
df_submission = pd.read_csv('sample_submission.csv')
df_submission.head()
# Out:
#    id  pressure
# 0   1         0
# 1   2         0
# 2   3         0
# 3   4         0
# 4   5         0

# %%
df_train.shape
# Out:
# (6036000, 8)

# %%
df_train.info()
df_train.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6036000 entries, 0 to 6035999
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   id         int64
#  1   breath_id  int64
#  2   R          int64
#  3   C          int64
#  4   time_step  float64
#  5   u_in       float64
#  6   u_out      int64
#  7   pressure   float64
# dtypes: float64(3), int64(5)
# memory usage: 368.4 MB
# id           0
# breath_id    0
# R            0
# C            0
# time_step    0
# u_in         0
# u_out        0
# pressure     0
# dtype: int64

# %% [markdown]
# #####  Train data sets

# %%
## Describe in exclude id columns
df_train[df_train.columns[1:]].describe(include='all').round(3)
# Out:
#          breath_id            R            C    time_step         u_in  \
# count  6036000.000  6036000.000  6036000.000  6036000.000  6036000.000
# mean     62838.859       27.036       26.081        1.307        7.322
# std      36335.256       19.595       17.152        0.766       13.435
# min          1.000        5.000       10.000        0.000        0.000
# 25%      31377.000        5.000       10.000        0.643        0.394
# 50%      62765.500       20.000       20.000        1.308        4.386
# 75%      94301.000       50.000       50.000        1.966        4.984
# max     125749.000       50.000       50.000        2.937      100.000
#
#              u_out     pressure
# count  6036000.000  6036000.000
# mean         0.620       11.220
# std          0.485        8.110
# min          0.000       -1.896
# 25%          0.000        6.330
# 50%          1.000        7.033
# 75%          1.000       13.641
# max          1.000       64.821

# %%
df_train['time_step'].diff()
# Out:
# 0               NaN
# 1          0.033652
# 2          0.033862
# 3          0.034028
# 4          0.034213
#              ...
# 6035995    0.033412
# 6035996    0.033358
# 6035997    0.033447
# 6035998    0.033337
# 6035999    0.033273
# Name: time_step, Length: 6036000, dtype: float64

# %%
df_train['R_C'] = [f'{r:02}_{c:02}' for r, c in zip(df_train['R'], df_train['C'])]
RCorder = list(np.sort(df_train['R_C'].unique()))

# %%
RCorder
# Out:
# ['05_10',
#  '05_20',
#  '05_50',
#  '20_10',
#  '20_20',
#  '20_50',
#  '50_10',
#  '50_20',
#  '50_50']

# %%
df_train['time_delta'] = df_train['time_step'].diff()
df_train['time_delta'].fillna(0, inplace=True)
df_train['time_delta'].mask(df_train['time_delta'] < 0, 0, inplace=True)
df_train['tmp'] = df_train['time_delta'] * df_train['u_in']
df_train['area'] = df_train.groupby('breath_id')['tmp'].cumsum()

# %%
# u_in: max, min, mean, std 
u_in_max_dict = df_train.groupby('breath_id')['u_in'].max().to_dict()
df_train['u_in_max'] = df_train['breath_id'].map(u_in_max_dict)
u_in_min_dict = df_train.groupby('breath_id')['u_in'].min().to_dict()
df_train['u_in_min'] = df_train['breath_id'].map(u_in_min_dict)
u_in_mean_dict = df_train.groupby('breath_id')['u_in'].mean().to_dict()
df_train['u_in_mean'] = df_train['breath_id'].map(u_in_mean_dict)
u_in_std_dict = df_train.groupby('breath_id')['u_in'].std().to_dict()
df_train['u_in_std'] = df_train['breath_id'].map(u_in_std_dict)

# %%
# u_in_half is time:0 - time point of u_out:1 rise (almost 1.0s)
df_train['tmp'] = df_train['u_out']*(-1)+1 # inversion of u_out
df_train['u_in_half'] = df_train['tmp'] * df_train['u_in']

# %%
# u_in_half: max, min, mean, std
u_in_half_max_dict = df_train.groupby('breath_id')['u_in_half'].max().to_dict()
df_train['u_in_half_max'] = df_train['breath_id'].map(u_in_half_max_dict)
u_in_half_min_dict = df_train.groupby('breath_id')['u_in_half'].min().to_dict()
df_train['u_in_half_min'] = df_train['breath_id'].map(u_in_half_min_dict)
u_in_half_mean_dict = df_train.groupby('breath_id')['u_in_half'].mean().to_dict()
df_train['u_in_half_mean'] = df_train['breath_id'].map(u_in_half_mean_dict)
u_in_half_std_dict = df_train.groupby('breath_id')['u_in_half'].std().to_dict()
df_train['u_in_half_std'] = df_train['breath_id'].map(u_in_half_std_dict)

# %%
# All entries are first point of each breath_id
first_df = df_train.loc[0::80,:]
# All entries are first point of each breath_id
last_df = df_train.loc[79::80,:]

# %%
df_train['u_out_diff'] = df_train['u_out'].diff()
df_train['u_out_diff'].fillna(0, inplace=True)
df_train['u_out_diff'].replace(-1, 0, inplace=True)
uout1_df = df_train[df_train['u_out_diff']==1]

# %%
# Register Area when u_out becomes 1
uout1_area_dict = dict(zip(first_df['breath_id'], first_df['u_in']))
df_train['area_uout1'] = df_train['breath_id'].map(uout1_area_dict)

# %%
# u_in: first point, last point
u_in_first_dict = dict(zip(first_df['breath_id'], first_df['u_in']))
df_train['u_in_first'] = df_train['breath_id'].map(u_in_first_dict)
u_in_last_dict = dict(zip(first_df['breath_id'], last_df['u_in']))
df_train['u_in_last'] = df_train['breath_id'].map(u_in_last_dict)
# time(sec) of end point
time_end_dict = dict(zip(last_df['breath_id'], last_df['time_step']))     
df_train['time_end'] = df_train['breath_id'].map(time_end_dict)

# %%
# time(sec) when u_out becomes 1
uout1_dict = dict(zip(uout1_df['breath_id'], uout1_df['time_step']))
df_train['time_uout1'] = df_train['breath_id'].map(uout1_dict)

# %%
# u_in when u_out becomes1
u_in_uout1_dict = dict(zip(uout1_df['breath_id'], uout1_df['u_in']))
df_train['u_in_uout1'] = df_train['breath_id'].map(u_in_uout1_dict)

# %%
# Dict that puts 0 at the beginning of the 80row cycle
first_0_dict = dict(zip(first_df['id'], [0]*len(uout1_df)))

# Faster version u_in_diff creation, faster than groupby
df_train['u_in_diff'] = df_train['u_in'].diff()
df_train['tmp'] = df_train['id'].map(first_0_dict) # put 0, the 80row cycle
df_train.iloc[0::80, df_train.columns.get_loc('u_in_diff')] = df_train.iloc[0::80, df_train.columns.get_loc('tmp')]

# %%
# Create u_in vibration
df_train['diff_sign'] = np.sign(df_train['u_in_diff'])
df_train['sign_diff'] = df_train['diff_sign'].diff()
df_train['tmp'] = df_train['id'].map(first_0_dict) # put 0, the 80row cycle
df_train.iloc[0::80, df_train.columns.get_loc('sign_diff')] = df_train.iloc[0::80, df_train.columns.get_loc('tmp')]

# Count the number of inversions, so take the absolute value and sum
df_train['sign_diff'] = abs(df_train['sign_diff']) 
sign_diff_dict = df_train.groupby('breath_id')['sign_diff'].sum().to_dict()
df_train['diff_vib'] = df_train['breath_id'].map(sign_diff_dict)

# %%
if 'diff_sign' in df_train.columns:
    df_train.drop(['diff_sign', 'sign_diff'], axis=1, inplace=True)

# %% [markdown]
# #####  Test data sets

# %%
df_test['time_step'].diff()
# Out:
# 0               NaN
# 1          0.031904
# 2          0.031924
# 3          0.031924
# 4          0.031893
#              ...
# 4023995    0.033753
# 4023996    0.033736
# 4023997    0.033622
# 4023998    0.033659
# 4023999    0.034167
# Name: time_step, Length: 4024000, dtype: float64

# %%
df_test['R_C'] = [f'{r:02}_{c:02}' for r, c in zip(df_test['R'], df_test['C'])]
Rcorder = list(np.sort(df_test['R_C'].unique()))

# %%
Rcorder
# Out:
# ['05_10',
#  '05_20',
#  '05_50',
#  '20_10',
#  '20_20',
#  '20_50',
#  '50_10',
#  '50_20',
#  '50_50']

# %%
df_test['time_delta'] = df_test['time_step'].diff()
df_test['time_delta'].fillna(0, inplace=True)
df_test['time_delta'].mask(df_test['time_delta'] < 0, 0, inplace=True)
df_test['tmp'] = df_test['time_delta'] * df_test['u_in']
df_test['area'] = df_test.groupby('breath_id')['tmp'].cumsum()

# %%
# u_in: max, min, mean, std 
u_in_max_dict = df_test.groupby('breath_id')['u_in'].max().to_dict()
df_test['u_in_max'] = df_test['breath_id'].map(u_in_max_dict)
u_in_min_dict = df_test.groupby('breath_id')['u_in'].min().to_dict()
df_test['u_in_min'] = df_test['breath_id'].map(u_in_min_dict)
u_in_mean_dict = df_test.groupby('breath_id')['u_in'].mean().to_dict()
df_test['u_in_mean'] = df_test['breath_id'].map(u_in_mean_dict)
u_in_std_dict = df_test.groupby('breath_id')['u_in'].std().to_dict()
df_test['u_in_std'] = df_test['breath_id'].map(u_in_std_dict)

# %%
# u_in_half is time:0 - time point of u_out:1 rise (almost 1.0s)
df_test['tmp'] = df_test['u_out']*(-1)+1 # inversion of u_out
df_test['u_in_half'] = df_test['tmp'] * df_test['u_in']

# %%
# u_in_half: max, min, mean, std
u_in_half_max_dict = df_test.groupby('breath_id')['u_in_half'].max().to_dict()
df_test['u_in_half_max'] = df_test['breath_id'].map(u_in_half_max_dict)
u_in_half_min_dict = df_test.groupby('breath_id')['u_in_half'].min().to_dict()
df_test['u_in_half_min'] = df_test['breath_id'].map(u_in_half_min_dict)
u_in_half_mean_dict = df_test.groupby('breath_id')['u_in_half'].mean().to_dict()
df_test['u_in_half_mean'] = df_test['breath_id'].map(u_in_half_mean_dict)
u_in_half_std_dict = df_test.groupby('breath_id')['u_in_half'].std().to_dict()
df_test['u_in_half_std'] = df_test['breath_id'].map(u_in_half_std_dict)

# %%
# All entries are first point of each breath_id
first_df = df_test.loc[0::80,:]
# All entries are first point of each breath_id
last_df = df_test.loc[79::80,:]

# %%
df_test['u_out_diff'] = df_test['u_out'].diff()
df_test['u_out_diff'].fillna(0, inplace=True)
df_test['u_out_diff'].replace(-1, 0, inplace=True)
uout1_df = df_test[df_test['u_out_diff']==1]

# %%
# Register Area when u_out becomes 1
uout1_area_dict = dict(zip(first_df['breath_id'], first_df['u_in']))
df_test['area_uout1'] = df_test['breath_id'].map(uout1_area_dict)

# %%
# u_in: first point, last point
u_in_first_dict = dict(zip(first_df['breath_id'], first_df['u_in']))
df_test['u_in_first'] = df_test['breath_id'].map(u_in_first_dict)
u_in_last_dict = dict(zip(first_df['breath_id'], last_df['u_in']))
df_test['u_in_last'] = df_test['breath_id'].map(u_in_last_dict)
# time(sec) of end point
time_end_dict = dict(zip(last_df['breath_id'], last_df['time_step']))     
df_test['time_end'] = df_test['breath_id'].map(time_end_dict)

# %%
# time(sec) when u_out becomes 1
uout1_dict = dict(zip(uout1_df['breath_id'], uout1_df['time_step']))
df_test['time_uout1'] = df_test['breath_id'].map(uout1_dict)

# %%
# u_in when u_out becomes1
u_in_uout1_dict = dict(zip(uout1_df['breath_id'], uout1_df['u_in']))
df_test['u_in_uout1'] = df_test['breath_id'].map(u_in_uout1_dict)

# %%
# Dict that puts 0 at the beginning of the 80row cycle
first_0_dict = dict(zip(first_df['id'], [0]*len(uout1_df)))

# Faster version u_in_diff creation, faster than groupby
df_test['u_in_diff'] = df_test['u_in'].diff()
df_test['tmp'] = df_test['id'].map(first_0_dict) # put 0, the 80row cycle
df_test.iloc[0::80, df_test.columns.get_loc('u_in_diff')] = df_test.iloc[0::80, df_test.columns.get_loc('tmp')]

# %%
# Create u_in vibration
df_test['diff_sign'] = np.sign(df_test['u_in_diff'])
df_test['sign_diff'] = df_test['diff_sign'].diff()
df_test['tmp'] = df_test['id'].map(first_0_dict) # put 0, the 80row cycle
df_test.iloc[0::80, df_test.columns.get_loc('sign_diff')] = df_test.iloc[0::80, df_test.columns.get_loc('tmp')]

# Count the number of inversions, so take the absolute value and sum
df_test['sign_diff'] = abs(df_test['sign_diff']) 
sign_diff_dict = df_test.groupby('breath_id')['sign_diff'].sum().to_dict()
df_test['diff_vib'] = df_test['breath_id'].map(sign_diff_dict)

# %%
if 'diff_sign' in df_test.columns:
    df_test.drop(['diff_sign', 'sign_diff'], axis=1, inplace=True)

# %%
print(len(df_train.columns))
print(len(df_test.columns))
# Out:
# 30
# 29

# %%
#Training and test data
X_train = df_train.drop(['id','breath_id','pressure','R_C','tmp'], axis = 1)
Y_train = df_train['pressure']
X_test = df_test.drop(['id','breath_id','R_C','tmp'], axis = 1).copy()
print("X_train shape: ", X_train.shape)
print("Y_train shape: ", Y_train.shape)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape:  (6036000, 25)
# Y_train shape:  (6036000,)
# X_test shape:  (4024000, 25)

# %%
len(X_train.columns)
# Out:
# 25

# %%
len(X_test.columns)
# Out:
# 25

# %%
X_test.isnull().sum()
# Out:
# R                 0
# C                 0
# time_step         0
# u_in              0
# u_out             0
# time_delta        0
# area              0
# u_in_max          0
# u_in_min          0
# u_in_mean         0
# u_in_std          0
# u_in_half         0
# u_in_half_max     0
# u_in_half_min     0
# u_in_half_mean    0
# u_in_half_std     0
# u_out_diff        0
# area_uout1        0
# u_in_first        0
# u_in_last         0
# time_end          0
# time_uout1        0
# u_in_uout1        0
# u_in_diff         0
# diff_vib          0
# dtype: int64

# %%
from sklearn.preprocessing import RobustScaler

# Create the object
sc=RobustScaler()
sc.fit(X_train,X_test ) 
X_train_scaled =sc.transform(X_train)
X_test_scaled  =sc.transform(X_test)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
logreg = LinearRegression()
logreg.fit(X_train_scaled,Y_train)
Y_pred = logreg.predict(X_test_scaled)
acclog = round(logreg.score(X_train_scaled,Y_train)*100,2)
acclog
# Out:
# 59.37

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree = DecisionTreeRegressor()
decision_tree.fit(X_train_scaled, Y_train)
Y_pred = decision_tree.predict(X_test_scaled)
acc_decision_tree = round(decision_tree.score(X_train_scaled, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 100.0

# %% [markdown]
# # Catboost Regressor

# %%
from catboost import CatBoostRegressor
catboost = CatBoostRegressor()
catboost.fit(X_train_scaled, Y_train)
Y_pred = catboost.predict(X_test_scaled)
acc_catboost = round(catboost.score(X_train_scaled, Y_train) * 100, 2)
# Out:
# Learning rate set to 0.183812
# 0:	learn: 6.9371400	total: 1.52s	remaining: 25m 15s
# 1:	learn: 6.0170305	total: 2.88s	remaining: 23m 56s
# 2:	learn: 5.3002851	total: 4.3s	remaining: 23m 50s
# 3:	learn: 4.7162979	total: 5.75s	remaining: 23m 50s
# 4:	learn: 4.2577423	total: 7.49s	remaining: 24m 50s
# 5:	learn: 3.9052548	total: 8.95s	remaining: 24m 42s
# 6:	learn: 3.6230092	total: 10.4s	remaining: 24m 34s
# 7:	learn: 3.4144605	total: 11.7s	remaining: 24m 15s
# 8:	learn: 3.2420088	total: 13.4s	remaining: 24m 39s
# 9:	learn: 3.0927610	total: 15.1s	remaining: 24m 59s
# 10:	learn: 2.9555576	total: 17.9s	remaining: 26m 52s
# 11:	learn: 2.8520728	total: 20.7s	remaining: 28m 20s
# 12:	learn: 2.7718692	total: 23.3s	remaining: 29m 28s
# 13:	learn: 2.6882738	total: 26.1s	remaining: 30m 34s
# 14:	learn: 2.6256707	total: 28.8s	remaining: 31m 28s
# 15:	learn: 2.5640909	total: 31.7s	remaining: 32m 30s
# 16:	learn: 2.5085874	total: 34.4s	remaining: 33m 11s
# 17:	learn: 2.4634217	total: 37.3s	remaining: 33m 54s
# 18:	learn: 2.4331057	total: 39.6s	remaining: 34m 6s
# 19:	learn: 2.4034835	total: 42s	remaining: 34m 19s
# 20:	learn: 2.3808638	total: 44.3s	remaining: 34m 23s
# 21:	learn: 2.3481256	total: 46.7s	remaining: 34m 36s
# 22:	learn: 2.3260994	total: 48.8s	remaining: 34m 32s
# 23:	learn: 2.2922619	total: 50.8s	remaining: 34m 26s
# 24:	learn: 2.2662501	total: 52.6s	remaining: 34m 11s
# 25:	learn: 2.2488985	total: 54.3s	remaining: 33m 53s
# 26:	learn: 2.2186057	total: 57.2s	remaining: 34m 19s
# 27:	learn: 2.2033384	total: 59.4s	remaining: 34m 22s
# 28:	learn: 2.1834454	total: 1m 1s	remaining: 34m 23s
# 29:	learn: 2.1521351	total: 1m 3s	remaining: 34m 25s
# 30:	learn: 2.1342138	total: 1m 6s	remaining: 34m 34s
# 31:	learn: 2.1063068	total: 1m 8s	remaining: 34m 39s
# 32:	learn: 2.0814400	total: 1m 11s	remaining: 34m 47s
# 33:	learn: 2.0712469	total: 1m 13s	remaining: 34m 35s
# 34:	learn: 2.0582788	total: 1m 14s	remaining: 34m 26s
# 35:	learn: 2.0428906	total: 1m 17s	remaining: 34m 21s
# 36:	learn: 2.0250199	total: 1m 18s	remaining: 34m 14s
# 37:	learn: 2.0129075	total: 1m 20s	remaining: 34m 6s
# 38:	learn: 2.0037824	total: 1m 22s	remaining: 33m 53s
# 39:	learn: 1.9929090	total: 1m 24s	remaining: 33m 49s
# 40:	learn: 1.9782334	total: 1m 26s	remaining: 33m 43s
# 41:	learn: 1.9708167	total: 1m 28s	remaining: 33m 31s
# 42:	learn: 1.9592069	total: 1m 30s	remaining: 33m 23s
# 43:	learn: 1.9420929	total: 1m 31s	remaining: 33m 17s
# 44:	learn: 1.9251999	total: 1m 33s	remaining: 33m 12s
# 45:	learn: 1.9169780	total: 1m 35s	remaining: 33m 4s
# 46:	learn: 1.9101942	total: 1m 37s	remaining: 32m 52s
# 47:	learn: 1.8923384	total: 1m 39s	remaining: 32m 48s
# 48:	learn: 1.8833499	total: 1m 41s	remaining: 32m 46s
# 49:	learn: 1.8720369	total: 1m 43s	remaining: 32m 47s
# 50:	learn: 1.8654330	total: 1m 46s	remaining: 32m 54s
# 51:	learn: 1.8528245	total: 1m 48s	remaining: 33m 7s
# 52:	learn: 1.8465735	total: 1m 51s	remaining: 33m 6s
# 53:	learn: 1.8375159	total: 1m 53s	remaining: 33m 1s
# 54:	learn: 1.8335134	total: 1m 54s	remaining: 32m 50s
# 55:	learn: 1.8253333	total: 1m 56s	remaining: 32m 45s
# 56:	learn: 1.8154644	total: 1m 58s	remaining: 32m 40s
# 57:	learn: 1.8015664	total: 2m	remaining: 32m 35s
# 58:	learn: 1.7931835	total: 2m 2s	remaining: 32m 27s
# 59:	learn: 1.7838353	total: 2m 3s	remaining: 32m 19s
# 60:	learn: 1.7765974	total: 2m 5s	remaining: 32m 13s
# 61:	learn: 1.7671514	total: 2m 7s	remaining: 32m 11s
# 62:	learn: 1.7608867	total: 2m 9s	remaining: 32m 6s
# 63:	learn: 1.7572880	total: 2m 11s	remaining: 31m 59s
# 64:	learn: 1.7501850	total: 2m 13s	remaining: 31m 54s
# 65:	learn: 1.7424892	total: 2m 15s	remaining: 31m 53s
# 66:	learn: 1.7371634	total: 2m 17s	remaining: 31m 49s
# 67:	learn: 1.7258645	total: 2m 18s	remaining: 31m 39s
# 68:	learn: 1.7194432	total: 2m 20s	remaining: 31m 37s
# 69:	learn: 1.7116402	total: 2m 22s	remaining: 31m 34s
# 70:	learn: 1.7065702	total: 2m 24s	remaining: 31m 29s
# 71:	learn: 1.7020016	total: 2m 26s	remaining: 31m 23s
# 72:	learn: 1.6974542	total: 2m 27s	remaining: 31m 17s
# 73:	learn: 1.6940264	total: 2m 29s	remaining: 31m 13s
# 74:	learn: 1.6849368	total: 2m 31s	remaining: 31m 11s
# 75:	learn: 1.6789991	total: 2m 33s	remaining: 31m 5s
# 76:	learn: 1.6713036	total: 2m 35s	remaining: 31m
# 77:	learn: 1.6656786	total: 2m 36s	remaining: 30m 54s
# 78:	learn: 1.6612613	total: 2m 39s	remaining: 30m 59s
# 79:	learn: 1.6569567	total: 2m 42s	remaining: 31m 4s
# 80:	learn: 1.6493527	total: 2m 44s	remaining: 31m 9s
# 81:	learn: 1.6435937	total: 2m 47s	remaining: 31m 10s
# 82:	learn: 1.6404120	total: 2m 49s	remaining: 31m 11s
# 83:	learn: 1.6355501	total: 2m 51s	remaining: 31m 12s
# 84:	learn: 1.6270701	total: 2m 53s	remaining: 31m 12s
# 85:	learn: 1.6206276	total: 2m 55s	remaining: 31m 6s
# 86:	learn: 1.6171409	total: 2m 57s	remaining: 30m 59s
# 87:	learn: 1.6108692	total: 2m 59s	remaining: 30m 55s
# 88:	learn: 1.6072721	total: 3m	remaining: 30m 52s
# 89:	learn: 1.6020850	total: 3m 2s	remaining: 30m 50s
# 90:	learn: 1.5960653	total: 3m 5s	remaining: 30m 48s
# 91:	learn: 1.5926930	total: 3m 6s	remaining: 30m 44s
# 92:	learn: 1.5865266	total: 3m 8s	remaining: 30m 38s
# 93:	learn: 1.5820610	total: 3m 10s	remaining: 30m 32s
# 94:	learn: 1.5789062	total: 3m 11s	remaining: 30m 27s
# 95:	learn: 1.5759678	total: 3m 13s	remaining: 30m 21s
# 96:	learn: 1.5695768	total: 3m 15s	remaining: 30m 18s
# 97:	learn: 1.5669088	total: 3m 17s	remaining: 30m 14s
# 98:	learn: 1.5616989	total: 3m 19s	remaining: 30m 11s
# 99:	learn: 1.5583357	total: 3m 20s	remaining: 30m 7s
# 100:	learn: 1.5543844	total: 3m 22s	remaining: 30m 3s
# 101:	learn: 1.5512620	total: 3m 24s	remaining: 30m
# 102:	learn: 1.5440857	total: 3m 26s	remaining: 29m 59s
# 103:	learn: 1.5413041	total: 3m 28s	remaining: 29m 55s
# 104:	learn: 1.5383055	total: 3m 30s	remaining: 29m 50s
# 105:	learn: 1.5356531	total: 3m 31s	remaining: 29m 46s
# 106:	learn: 1.5305418	total: 3m 33s	remaining: 29m 45s
# 107:	learn: 1.5285856	total: 3m 35s	remaining: 29m 43s
# 108:	learn: 1.5241614	total: 3m 37s	remaining: 29m 38s
# 109:	learn: 1.5197259	total: 3m 39s	remaining: 29m 36s
# 110:	learn: 1.5168844	total: 3m 41s	remaining: 29m 31s
# 111:	learn: 1.5151358	total: 3m 42s	remaining: 29m 24s
# 112:	learn: 1.5109039	total: 3m 44s	remaining: 29m 22s
# 113:	learn: 1.5076524	total: 3m 47s	remaining: 29m 26s
# 114:	learn: 1.5032324	total: 3m 49s	remaining: 29m 28s
# 115:	learn: 1.5004481	total: 3m 52s	remaining: 29m 29s
# 116:	learn: 1.4961570	total: 3m 54s	remaining: 29m 31s
# 117:	learn: 1.4925384	total: 3m 57s	remaining: 29m 31s
# 118:	learn: 1.4881456	total: 3m 59s	remaining: 29m 32s
# 119:	learn: 1.4834203	total: 4m 1s	remaining: 29m 33s
# 120:	learn: 1.4803968	total: 4m 3s	remaining: 29m 31s
# 121:	learn: 1.4770540	total: 4m 5s	remaining: 29m 29s
# 122:	learn: 1.4742848	total: 4m 8s	remaining: 29m 28s
# 123:	learn: 1.4708041	total: 4m 10s	remaining: 29m 28s
# 124:	learn: 1.4685473	total: 4m 12s	remaining: 29m 24s
# 125:	learn: 1.4660932	total: 4m 13s	remaining: 29m 20s
# 126:	learn: 1.4648508	total: 4m 15s	remaining: 29m 15s
# 127:	learn: 1.4613133	total: 4m 17s	remaining: 29m 12s
# 128:	learn: 1.4597792	total: 4m 19s	remaining: 29m 8s
# 129:	learn: 1.4569268	total: 4m 20s	remaining: 29m 5s
# 130:	learn: 1.4543539	total: 4m 22s	remaining: 29m 2s
# 131:	learn: 1.4524704	total: 4m 24s	remaining: 28m 59s
# 132:	learn: 1.4491178	total: 4m 26s	remaining: 29m
# 133:	learn: 1.4472299	total: 4m 29s	remaining: 28m 59s
# 134:	learn: 1.4445040	total: 4m 30s	remaining: 28m 55s
# 135:	learn: 1.4420762	total: 4m 32s	remaining: 28m 51s
# 136:	learn: 1.4402245	total: 4m 34s	remaining: 28m 47s
# 137:	learn: 1.4383639	total: 4m 36s	remaining: 28m 44s
# 138:	learn: 1.4371113	total: 4m 37s	remaining: 28m 40s
# 139:	learn: 1.4346957	total: 4m 39s	remaining: 28m 37s
# 140:	learn: 1.4311634	total: 4m 41s	remaining: 28m 34s
# 141:	learn: 1.4294223	total: 4m 43s	remaining: 28m 30s
# 142:	learn: 1.4270259	total: 4m 44s	remaining: 28m 27s
# 143:	learn: 1.4252134	total: 4m 46s	remaining: 28m 23s
# 144:	learn: 1.4207477	total: 4m 48s	remaining: 28m 20s
# 145:	learn: 1.4188533	total: 4m 50s	remaining: 28m 18s
# 146:	learn: 1.4163148	total: 4m 52s	remaining: 28m 17s
# 147:	learn: 1.4136689	total: 4m 54s	remaining: 28m 15s
# 148:	learn: 1.4103132	total: 4m 56s	remaining: 28m 13s
# 149:	learn: 1.4085476	total: 4m 58s	remaining: 28m 9s
# 150:	learn: 1.4073614	total: 4m 59s	remaining: 28m 5s
# 151:	learn: 1.4058952	total: 5m 1s	remaining: 28m 2s
# 152:	learn: 1.4041861	total: 5m 3s	remaining: 27m 58s
# 153:	learn: 1.4018848	total: 5m 5s	remaining: 27m 56s
# 154:	learn: 1.3996557	total: 5m 7s	remaining: 27m 55s
# 155:	learn: 1.3977605	total: 5m 9s	remaining: 27m 53s
# 156:	learn: 1.3948073	total: 5m 11s	remaining: 27m 52s
# 157:	learn: 1.3918468	total: 5m 13s	remaining: 27m 53s
# 158:	learn: 1.3902911	total: 5m 15s	remaining: 27m 51s
# 159:	learn: 1.3885742	total: 5m 18s	remaining: 27m 50s
# 160:	learn: 1.3866298	total: 5m 20s	remaining: 27m 51s
# 161:	learn: 1.3832706	total: 5m 23s	remaining: 27m 53s
# 162:	learn: 1.3812608	total: 5m 25s	remaining: 27m 51s
# 163:	learn: 1.3797121	total: 5m 26s	remaining: 27m 45s
# 164:	learn: 1.3771939	total: 5m 28s	remaining: 27m 39s
# 165:	learn: 1.3759049	total: 5m 29s	remaining: 27m 33s
# 166:	learn: 1.3741309	total: 5m 30s	remaining: 27m 28s
# 167:	learn: 1.3728222	total: 5m 31s	remaining: 27m 23s
# 168:	learn: 1.3710199	total: 5m 32s	remaining: 27m 17s
# 169:	learn: 1.3679399	total: 5m 34s	remaining: 27m 10s
# 170:	learn: 1.3654774	total: 5m 36s	remaining: 27m 9s
# 171:	learn: 1.3643845	total: 5m 37s	remaining: 27m 4s
# 172:	learn: 1.3612806	total: 5m 39s	remaining: 27m 2s
# 173:	learn: 1.3596637	total: 5m 40s	remaining: 26m 58s
# 174:	learn: 1.3576922	total: 5m 42s	remaining: 26m 55s
# 175:	learn: 1.3549891	total: 5m 44s	remaining: 26m 52s
# 176:	learn: 1.3534213	total: 5m 46s	remaining: 26m 49s
# 177:	learn: 1.3528667	total: 5m 47s	remaining: 26m 43s
# 178:	learn: 1.3512540	total: 5m 48s	remaining: 26m 38s
# 179:	learn: 1.3493308	total: 5m 49s	remaining: 26m 33s
# 180:	learn: 1.3480166	total: 5m 51s	remaining: 26m 28s
# 181:	learn: 1.3469683	total: 5m 52s	remaining: 26m 23s
# 182:	learn: 1.3449279	total: 5m 53s	remaining: 26m 18s
# 183:	learn: 1.3429527	total: 5m 54s	remaining: 26m 13s
# 184:	learn: 1.3407876	total: 5m 56s	remaining: 26m 8s
# 185:	learn: 1.3398998	total: 5m 57s	remaining: 26m 3s
# 186:	learn: 1.3388318	total: 5m 58s	remaining: 25m 58s
# 187:	learn: 1.3378684	total: 5m 59s	remaining: 25m 53s
# 188:	learn: 1.3361459	total: 6m	remaining: 25m 48s
# 189:	learn: 1.3347863	total: 6m 2s	remaining: 25m 43s
# 190:	learn: 1.3332173	total: 6m 3s	remaining: 25m 39s
# 191:	learn: 1.3314751	total: 6m 4s	remaining: 25m 35s
# 192:	learn: 1.3297937	total: 6m 6s	remaining: 25m 32s
# 193:	learn: 1.3285041	total: 6m 8s	remaining: 25m 28s
# 194:	learn: 1.3270082	total: 6m 9s	remaining: 25m 25s
# 195:	learn: 1.3255400	total: 6m 11s	remaining: 25m 23s
# 196:	learn: 1.3242530	total: 6m 13s	remaining: 25m 20s
# 197:	learn: 1.3233205	total: 6m 14s	remaining: 25m 17s
# 198:	learn: 1.3204161	total: 6m 16s	remaining: 25m 14s
# 199:	learn: 1.3196136	total: 6m 17s	remaining: 25m 11s
# 200:	learn: 1.3175476	total: 6m 19s	remaining: 25m 9s
# 201:	learn: 1.3160039	total: 6m 21s	remaining: 25m 5s
# 202:	learn: 1.3145621	total: 6m 22s	remaining: 25m 3s
# 203:	learn: 1.3127114	total: 6m 24s	remaining: 24m 59s
# 204:	learn: 1.3116709	total: 6m 25s	remaining: 24m 55s
# 205:	learn: 1.3090329	total: 6m 27s	remaining: 24m 53s
# 206:	learn: 1.3080052	total: 6m 28s	remaining: 24m 49s
# 207:	learn: 1.3065279	total: 6m 30s	remaining: 24m 45s
# 208:	learn: 1.3051566	total: 6m 31s	remaining: 24m 40s
# 209:	learn: 1.3041655	total: 6m 32s	remaining: 24m 36s
# 210:	learn: 1.3025500	total: 6m 34s	remaining: 24m 33s
# 211:	learn: 1.3012730	total: 6m 35s	remaining: 24m 30s
# 212:	learn: 1.3001695	total: 6m 36s	remaining: 24m 25s
# 213:	learn: 1.2976995	total: 6m 37s	remaining: 24m 21s
# 214:	learn: 1.2965156	total: 6m 39s	remaining: 24m 17s
# 215:	learn: 1.2955459	total: 6m 40s	remaining: 24m 15s
# 216:	learn: 1.2930502	total: 6m 42s	remaining: 24m 13s
# 217:	learn: 1.2919568	total: 6m 44s	remaining: 24m 10s
# 218:	learn: 1.2906277	total: 6m 45s	remaining: 24m 7s
# 219:	learn: 1.2895693	total: 6m 47s	remaining: 24m 3s
# 220:	learn: 1.2874160	total: 6m 48s	remaining: 24m
# 221:	learn: 1.2860321	total: 6m 50s	remaining: 23m 57s
# 222:	learn: 1.2846974	total: 6m 51s	remaining: 23m 54s
# 223:	learn: 1.2839184	total: 6m 53s	remaining: 23m 51s
# 224:	learn: 1.2821873	total: 6m 54s	remaining: 23m 47s
# 225:	learn: 1.2805927	total: 6m 55s	remaining: 23m 44s
# 226:	learn: 1.2780340	total: 6m 57s	remaining: 23m 40s
# 227:	learn: 1.2762163	total: 6m 58s	remaining: 23m 37s
# 228:	learn: 1.2746655	total: 7m	remaining: 23m 34s
# 229:	learn: 1.2732575	total: 7m 1s	remaining: 23m 30s
# 230:	learn: 1.2708014	total: 7m 2s	remaining: 23m 27s
# 231:	learn: 1.2698411	total: 7m 3s	remaining: 23m 23s
# 232:	learn: 1.2691508	total: 7m 5s	remaining: 23m 20s
# 233:	learn: 1.2683570	total: 7m 6s	remaining: 23m 15s
# 234:	learn: 1.2674544	total: 7m 7s	remaining: 23m 11s
# 235:	learn: 1.2665801	total: 7m 8s	remaining: 23m 7s
# 236:	learn: 1.2650765	total: 7m 9s	remaining: 23m 3s
# 237:	learn: 1.2637636	total: 7m 11s	remaining: 23m
# 238:	learn: 1.2626123	total: 7m 12s	remaining: 22m 56s
# 239:	learn: 1.2606575	total: 7m 13s	remaining: 22m 53s
# 240:	learn: 1.2598981	total: 7m 14s	remaining: 22m 49s
# 241:	learn: 1.2577875	total: 7m 16s	remaining: 22m 46s
# 242:	learn: 1.2568990	total: 7m 17s	remaining: 22m 43s
# 243:	learn: 1.2563386	total: 7m 19s	remaining: 22m 41s
# 244:	learn: 1.2554872	total: 7m 20s	remaining: 22m 38s
# 245:	learn: 1.2542815	total: 7m 22s	remaining: 22m 35s
# 246:	learn: 1.2530845	total: 7m 23s	remaining: 22m 32s
# 247:	learn: 1.2518863	total: 7m 25s	remaining: 22m 30s
# 248:	learn: 1.2510281	total: 7m 26s	remaining: 22m 27s
# 249:	learn: 1.2505228	total: 7m 27s	remaining: 22m 23s
# 250:	learn: 1.2494266	total: 7m 29s	remaining: 22m 20s
# 251:	learn: 1.2483459	total: 7m 30s	remaining: 22m 17s
# 252:	learn: 1.2477611	total: 7m 31s	remaining: 22m 13s
# 253:	learn: 1.2469008	total: 7m 32s	remaining: 22m 9s
# 254:	learn: 1.2453784	total: 7m 34s	remaining: 22m 6s
# 255:	learn: 1.2441107	total: 7m 35s	remaining: 22m 2s
# 256:	learn: 1.2434942	total: 7m 36s	remaining: 21m 59s
# 257:	learn: 1.2423121	total: 7m 37s	remaining: 21m 55s
# 258:	learn: 1.2413783	total: 7m 38s	remaining: 21m 52s
# 259:	learn: 1.2404052	total: 7m 40s	remaining: 21m 49s
# 260:	learn: 1.2398409	total: 7m 41s	remaining: 21m 45s
# 261:	learn: 1.2387254	total: 7m 42s	remaining: 21m 42s
# 262:	learn: 1.2376628	total: 7m 44s	remaining: 21m 40s
# 263:	learn: 1.2364692	total: 7m 45s	remaining: 21m 38s
# 264:	learn: 1.2344552	total: 7m 47s	remaining: 21m 36s
# 265:	learn: 1.2338448	total: 7m 48s	remaining: 21m 33s
# 266:	learn: 1.2329780	total: 7m 50s	remaining: 21m 30s
# 267:	learn: 1.2320789	total: 7m 51s	remaining: 21m 28s
# 268:	learn: 1.2310290	total: 7m 53s	remaining: 21m 26s
# 269:	learn: 1.2302499	total: 7m 55s	remaining: 21m 25s
# 270:	learn: 1.2292375	total: 7m 57s	remaining: 21m 23s
# 271:	learn: 1.2277037	total: 7m 59s	remaining: 21m 22s
# 272:	learn: 1.2260201	total: 8m	remaining: 21m 20s
# 273:	learn: 1.2252888	total: 8m 2s	remaining: 21m 17s
# 274:	learn: 1.2241523	total: 8m 3s	remaining: 21m 15s
# 275:	learn: 1.2237148	total: 8m 5s	remaining: 21m 12s
# 276:	learn: 1.2225056	total: 8m 6s	remaining: 21m 10s
# 277:	learn: 1.2218144	total: 8m 7s	remaining: 21m 7s
# 278:	learn: 1.2208026	total: 8m 9s	remaining: 21m 4s
# 279:	learn: 1.2199621	total: 8m 10s	remaining: 21m 1s
# 280:	learn: 1.2190255	total: 8m 11s	remaining: 20m 58s
# 281:	learn: 1.2176352	total: 8m 13s	remaining: 20m 55s
# 282:	learn: 1.2170634	total: 8m 14s	remaining: 20m 52s
# 283:	learn: 1.2163222	total: 8m 15s	remaining: 20m 49s
# 284:	learn: 1.2154917	total: 8m 16s	remaining: 20m 46s
# 285:	learn: 1.2145073	total: 8m 18s	remaining: 20m 44s
# 286:	learn: 1.2141583	total: 8m 19s	remaining: 20m 41s
# 287:	learn: 1.2134754	total: 8m 20s	remaining: 20m 38s
# 288:	learn: 1.2126005	total: 8m 22s	remaining: 20m 35s
# 289:	learn: 1.2118975	total: 8m 23s	remaining: 20m 32s
# 290:	learn: 1.2111916	total: 8m 24s	remaining: 20m 28s
# 291:	learn: 1.2100515	total: 8m 25s	remaining: 20m 26s
# 292:	learn: 1.2093344	total: 8m 26s	remaining: 20m 22s
# 293:	learn: 1.2082714	total: 8m 28s	remaining: 20m 20s
# 294:	learn: 1.2074894	total: 8m 29s	remaining: 20m 17s
# 295:	learn: 1.2067904	total: 8m 30s	remaining: 20m 14s
# 296:	learn: 1.2063845	total: 8m 32s	remaining: 20m 12s
# 297:	learn: 1.2059600	total: 8m 33s	remaining: 20m 9s
# 298:	learn: 1.2053864	total: 8m 34s	remaining: 20m 6s
# 299:	learn: 1.2046980	total: 8m 35s	remaining: 20m 3s
# 300:	learn: 1.2043360	total: 8m 36s	remaining: 20m
# 301:	learn: 1.2037472	total: 8m 37s	remaining: 19m 56s
# 302:	learn: 1.2029596	total: 8m 39s	remaining: 19m 53s
# 303:	learn: 1.2025976	total: 8m 40s	remaining: 19m 51s
# 304:	learn: 1.2003954	total: 8m 41s	remaining: 19m 48s
# 305:	learn: 1.1995803	total: 8m 42s	remaining: 19m 45s
# 306:	learn: 1.1988442	total: 8m 43s	remaining: 19m 42s
# 307:	learn: 1.1978460	total: 8m 45s	remaining: 19m 39s
# 308:	learn: 1.1974824	total: 8m 46s	remaining: 19m 36s
# 309:	learn: 1.1963263	total: 8m 47s	remaining: 19m 33s
# 310:	learn: 1.1954664	total: 8m 48s	remaining: 19m 31s
# 311:	learn: 1.1943988	total: 8m 49s	remaining: 19m 28s
# 312:	learn: 1.1923753	total: 8m 51s	remaining: 19m 26s
# 313:	learn: 1.1916586	total: 8m 52s	remaining: 19m 23s
# 314:	learn: 1.1903977	total: 8m 53s	remaining: 19m 21s
# 315:	learn: 1.1897497	total: 8m 55s	remaining: 19m 18s
# 316:	learn: 1.1888758	total: 8m 56s	remaining: 19m 15s
# 317:	learn: 1.1884025	total: 8m 57s	remaining: 19m 12s
# 318:	learn: 1.1869829	total: 8m 58s	remaining: 19m 10s
# 319:	learn: 1.1863129	total: 9m	remaining: 19m 7s
# 320:	learn: 1.1858097	total: 9m 1s	remaining: 19m 4s
# 321:	learn: 1.1849804	total: 9m 2s	remaining: 19m 2s
# 322:	learn: 1.1841460	total: 9m 4s	remaining: 19m
# 323:	learn: 1.1832220	total: 9m 5s	remaining: 18m 58s
# 324:	learn: 1.1818329	total: 9m 7s	remaining: 18m 57s
# 325:	learn: 1.1811873	total: 9m 9s	remaining: 18m 55s
# 326:	learn: 1.1804183	total: 9m 11s	remaining: 18m 54s
# 327:	learn: 1.1794833	total: 9m 12s	remaining: 18m 52s
# 328:	learn: 1.1787573	total: 9m 14s	remaining: 18m 50s
# 329:	learn: 1.1783796	total: 9m 15s	remaining: 18m 48s
# 330:	learn: 1.1779472	total: 9m 17s	remaining: 18m 46s
# 331:	learn: 1.1769609	total: 9m 18s	remaining: 18m 44s
# 332:	learn: 1.1763555	total: 9m 20s	remaining: 18m 42s
# 333:	learn: 1.1756274	total: 9m 21s	remaining: 18m 40s
# 334:	learn: 1.1750195	total: 9m 23s	remaining: 18m 38s
# 335:	learn: 1.1742750	total: 9m 25s	remaining: 18m 36s
# 336:	learn: 1.1738255	total: 9m 26s	remaining: 18m 34s
# 337:	learn: 1.1730002	total: 9m 27s	remaining: 18m 32s
# 338:	learn: 1.1726119	total: 9m 29s	remaining: 18m 29s
# 339:	learn: 1.1713747	total: 9m 30s	remaining: 18m 27s
# 340:	learn: 1.1705233	total: 9m 31s	remaining: 18m 24s
# 341:	learn: 1.1700382	total: 9m 33s	remaining: 18m 22s
# 342:	learn: 1.1697676	total: 9m 34s	remaining: 18m 19s
# 343:	learn: 1.1692890	total: 9m 35s	remaining: 18m 16s
# 344:	learn: 1.1686868	total: 9m 36s	remaining: 18m 14s
# 345:	learn: 1.1680902	total: 9m 37s	remaining: 18m 12s
# 346:	learn: 1.1677324	total: 9m 39s	remaining: 18m 10s
# 347:	learn: 1.1672169	total: 9m 40s	remaining: 18m 8s
# 348:	learn: 1.1665212	total: 9m 42s	remaining: 18m 6s
# 349:	learn: 1.1658929	total: 9m 44s	remaining: 18m 5s
# 350:	learn: 1.1656019	total: 9m 45s	remaining: 18m 2s
# 351:	learn: 1.1648581	total: 9m 47s	remaining: 18m
# 352:	learn: 1.1643441	total: 9m 48s	remaining: 17m 58s
# 353:	learn: 1.1639233	total: 9m 50s	remaining: 17m 56s
# 354:	learn: 1.1632744	total: 9m 51s	remaining: 17m 55s
# 355:	learn: 1.1627819	total: 9m 53s	remaining: 17m 53s
# 356:	learn: 1.1619090	total: 9m 54s	remaining: 17m 51s
# 357:	learn: 1.1615272	total: 9m 56s	remaining: 17m 49s
# 358:	learn: 1.1605916	total: 9m 57s	remaining: 17m 46s
# 359:	learn: 1.1598910	total: 9m 58s	remaining: 17m 44s
# 360:	learn: 1.1592691	total: 10m	remaining: 17m 42s
# 361:	learn: 1.1581585	total: 10m 1s	remaining: 17m 40s
# 362:	learn: 1.1575936	total: 10m 2s	remaining: 17m 37s
# 363:	learn: 1.1571064	total: 10m 3s	remaining: 17m 35s
# 364:	learn: 1.1566414	total: 10m 5s	remaining: 17m 32s
# 365:	learn: 1.1562147	total: 10m 6s	remaining: 17m 29s
# 366:	learn: 1.1556581	total: 10m 7s	remaining: 17m 28s
# 367:	learn: 1.1543083	total: 10m 9s	remaining: 17m 27s
# 368:	learn: 1.1538222	total: 10m 11s	remaining: 17m 24s
# 369:	learn: 1.1534437	total: 10m 12s	remaining: 17m 23s
# 370:	learn: 1.1525601	total: 10m 14s	remaining: 17m 21s
# 371:	learn: 1.1517805	total: 10m 15s	remaining: 17m 19s
# 372:	learn: 1.1509747	total: 10m 16s	remaining: 17m 16s
# 373:	learn: 1.1499605	total: 10m 17s	remaining: 17m 14s
# 374:	learn: 1.1493296	total: 10m 19s	remaining: 17m 11s
# 375:	learn: 1.1486770	total: 10m 20s	remaining: 17m 9s
# 376:	learn: 1.1480197	total: 10m 21s	remaining: 17m 7s
# 377:	learn: 1.1470562	total: 10m 22s	remaining: 17m 4s
# 378:	learn: 1.1462538	total: 10m 23s	remaining: 17m 2s
# 379:	learn: 1.1459401	total: 10m 25s	remaining: 17m
# 380:	learn: 1.1454841	total: 10m 26s	remaining: 16m 58s
# 381:	learn: 1.1449046	total: 10m 28s	remaining: 16m 56s
# 382:	learn: 1.1446332	total: 10m 29s	remaining: 16m 53s
# 383:	learn: 1.1441856	total: 10m 30s	remaining: 16m 51s
# 384:	learn: 1.1436651	total: 10m 32s	remaining: 16m 50s
# 385:	learn: 1.1426654	total: 10m 33s	remaining: 16m 48s
# 386:	learn: 1.1420955	total: 10m 35s	remaining: 16m 46s
# 387:	learn: 1.1412064	total: 10m 36s	remaining: 16m 43s
# 388:	learn: 1.1404883	total: 10m 38s	remaining: 16m 42s
# 389:	learn: 1.1399778	total: 10m 39s	remaining: 16m 40s
# 390:	learn: 1.1395081	total: 10m 41s	remaining: 16m 38s
# 391:	learn: 1.1388401	total: 10m 42s	remaining: 16m 36s
# 392:	learn: 1.1380719	total: 10m 43s	remaining: 16m 34s
# 393:	learn: 1.1375400	total: 10m 45s	remaining: 16m 32s
# 394:	learn: 1.1371643	total: 10m 46s	remaining: 16m 30s
# 395:	learn: 1.1366488	total: 10m 47s	remaining: 16m 28s
# 396:	learn: 1.1363036	total: 10m 49s	remaining: 16m 25s
# 397:	learn: 1.1358604	total: 10m 50s	remaining: 16m 23s
# 398:	learn: 1.1354804	total: 10m 51s	remaining: 16m 21s
# 399:	learn: 1.1345999	total: 10m 53s	remaining: 16m 19s
# 400:	learn: 1.1340798	total: 10m 54s	remaining: 16m 17s
# 401:	learn: 1.1328320	total: 10m 56s	remaining: 16m 16s
# 402:	learn: 1.1321628	total: 10m 57s	remaining: 16m 14s
# 403:	learn: 1.1316277	total: 10m 59s	remaining: 16m 12s
# 404:	learn: 1.1310755	total: 11m	remaining: 16m 10s
# 405:	learn: 1.1306473	total: 11m 1s	remaining: 16m 8s
# 406:	learn: 1.1296606	total: 11m 3s	remaining: 16m 6s
# 407:	learn: 1.1293154	total: 11m 4s	remaining: 16m 3s
# 408:	learn: 1.1286276	total: 11m 5s	remaining: 16m 1s
# 409:	learn: 1.1282171	total: 11m 7s	remaining: 15m 59s
# 410:	learn: 1.1276813	total: 11m 8s	remaining: 15m 57s
# 411:	learn: 1.1270338	total: 11m 9s	remaining: 15m 55s
# 412:	learn: 1.1263913	total: 11m 10s	remaining: 15m 53s
# 413:	learn: 1.1260383	total: 11m 12s	remaining: 15m 51s
# 414:	learn: 1.1254294	total: 11m 13s	remaining: 15m 49s
# 415:	learn: 1.1249946	total: 11m 14s	remaining: 15m 47s
# 416:	learn: 1.1246523	total: 11m 15s	remaining: 15m 44s
# 417:	learn: 1.1244147	total: 11m 17s	remaining: 15m 43s
# 418:	learn: 1.1239155	total: 11m 18s	remaining: 15m 41s
# 419:	learn: 1.1233385	total: 11m 20s	remaining: 15m 39s
# 420:	learn: 1.1229012	total: 11m 21s	remaining: 15m 37s
# 421:	learn: 1.1219887	total: 11m 23s	remaining: 15m 35s
# 422:	learn: 1.1213397	total: 11m 24s	remaining: 15m 33s
# 423:	learn: 1.1210069	total: 11m 25s	remaining: 15m 31s
# 424:	learn: 1.1205902	total: 11m 27s	remaining: 15m 29s
# 425:	learn: 1.1203147	total: 11m 28s	remaining: 15m 27s
# 426:	learn: 1.1196957	total: 11m 29s	remaining: 15m 25s
# 427:	learn: 1.1192995	total: 11m 30s	remaining: 15m 23s
# 428:	learn: 1.1190085	total: 11m 32s	remaining: 15m 21s
# 429:	learn: 1.1180148	total: 11m 33s	remaining: 15m 19s
# 430:	learn: 1.1170989	total: 11m 34s	remaining: 15m 17s
# 431:	learn: 1.1164636	total: 11m 36s	remaining: 15m 15s
# 432:	learn: 1.1161693	total: 11m 37s	remaining: 15m 13s
# 433:	learn: 1.1158336	total: 11m 38s	remaining: 15m 11s
# 434:	learn: 1.1154264	total: 11m 40s	remaining: 15m 9s
# 435:	learn: 1.1148979	total: 11m 41s	remaining: 15m 7s
# 436:	learn: 1.1145647	total: 11m 43s	remaining: 15m 6s
# 437:	learn: 1.1137359	total: 11m 44s	remaining: 15m 4s
# 438:	learn: 1.1130199	total: 11m 46s	remaining: 15m 2s
# 439:	learn: 1.1123907	total: 11m 47s	remaining: 15m
# 440:	learn: 1.1119460	total: 11m 48s	remaining: 14m 58s
# 441:	learn: 1.1116948	total: 11m 50s	remaining: 14m 56s
# 442:	learn: 1.1110695	total: 11m 52s	remaining: 14m 55s
# 443:	learn: 1.1107760	total: 11m 54s	remaining: 14m 54s
# 444:	learn: 1.1100404	total: 11m 57s	remaining: 14m 54s
# 445:	learn: 1.1093678	total: 11m 59s	remaining: 14m 53s
# 446:	learn: 1.1088877	total: 12m	remaining: 14m 51s
# 447:	learn: 1.1084853	total: 12m 2s	remaining: 14m 49s
# 448:	learn: 1.1081171	total: 12m 3s	remaining: 14m 48s
# 449:	learn: 1.1075381	total: 12m 5s	remaining: 14m 46s
# 450:	learn: 1.1071985	total: 12m 6s	remaining: 14m 44s
# 451:	learn: 1.1066703	total: 12m 8s	remaining: 14m 43s
# 452:	learn: 1.1060134	total: 12m 9s	remaining: 14m 41s
# 453:	learn: 1.1056520	total: 12m 11s	remaining: 14m 39s
# 454:	learn: 1.1049747	total: 12m 12s	remaining: 14m 37s
# 455:	learn: 1.1045355	total: 12m 13s	remaining: 14m 34s
# 456:	learn: 1.1043648	total: 12m 14s	remaining: 14m 32s
# 457:	learn: 1.1038376	total: 12m 15s	remaining: 14m 30s
# 458:	learn: 1.1028597	total: 12m 16s	remaining: 14m 28s
# 459:	learn: 1.1019415	total: 12m 18s	remaining: 14m 26s
# 460:	learn: 1.1016269	total: 12m 19s	remaining: 14m 24s
# 461:	learn: 1.1010851	total: 12m 20s	remaining: 14m 22s
# 462:	learn: 1.1007873	total: 12m 22s	remaining: 14m 20s
# 463:	learn: 1.1004174	total: 12m 23s	remaining: 14m 18s
# 464:	learn: 1.0998373	total: 12m 24s	remaining: 14m 16s
# 465:	learn: 1.0996382	total: 12m 25s	remaining: 14m 14s
# 466:	learn: 1.0994042	total: 12m 26s	remaining: 14m 12s
# 467:	learn: 1.0987185	total: 12m 27s	remaining: 14m 10s
# 468:	learn: 1.0978867	total: 12m 28s	remaining: 14m 7s
# 469:	learn: 1.0975752	total: 12m 29s	remaining: 14m 5s
# 470:	learn: 1.0969495	total: 12m 31s	remaining: 14m 3s
# 471:	learn: 1.0964601	total: 12m 32s	remaining: 14m 1s
# 472:	learn: 1.0959323	total: 12m 33s	remaining: 13m 59s
# 473:	learn: 1.0952708	total: 12m 35s	remaining: 13m 58s
# 474:	learn: 1.0948385	total: 12m 37s	remaining: 13m 57s
# 475:	learn: 1.0943373	total: 12m 39s	remaining: 13m 55s
# 476:	learn: 1.0938976	total: 12m 40s	remaining: 13m 54s
# 477:	learn: 1.0936790	total: 12m 42s	remaining: 13m 52s
# 478:	learn: 1.0930966	total: 12m 43s	remaining: 13m 50s
# 479:	learn: 1.0925495	total: 12m 45s	remaining: 13m 48s
# 480:	learn: 1.0921722	total: 12m 46s	remaining: 13m 46s
# 481:	learn: 1.0919252	total: 12m 47s	remaining: 13m 45s
# 482:	learn: 1.0915645	total: 12m 49s	remaining: 13m 43s
# 483:	learn: 1.0911018	total: 12m 50s	remaining: 13m 41s
# 484:	learn: 1.0904812	total: 12m 51s	remaining: 13m 39s
# 485:	learn: 1.0900628	total: 12m 53s	remaining: 13m 38s
# 486:	learn: 1.0897002	total: 12m 54s	remaining: 13m 36s
# 487:	learn: 1.0892407	total: 12m 56s	remaining: 13m 34s
# 488:	learn: 1.0887918	total: 12m 57s	remaining: 13m 32s
# 489:	learn: 1.0885620	total: 12m 59s	remaining: 13m 30s
# 490:	learn: 1.0882843	total: 13m	remaining: 13m 29s
# 491:	learn: 1.0878533	total: 13m 2s	remaining: 13m 27s
# 492:	learn: 1.0872935	total: 13m 3s	remaining: 13m 26s
# 493:	learn: 1.0868943	total: 13m 5s	remaining: 13m 24s
# 494:	learn: 1.0864729	total: 13m 6s	remaining: 13m 22s
# 495:	learn: 1.0856691	total: 13m 7s	remaining: 13m 20s
# 496:	learn: 1.0854180	total: 13m 8s	remaining: 13m 18s
# 497:	learn: 1.0851032	total: 13m 9s	remaining: 13m 16s
# 498:	learn: 1.0847896	total: 13m 11s	remaining: 13m 14s
# 499:	learn: 1.0842706	total: 13m 12s	remaining: 13m 12s
# 500:	learn: 1.0839435	total: 13m 13s	remaining: 13m 9s
# 501:	learn: 1.0832323	total: 13m 14s	remaining: 13m 7s
# 502:	learn: 1.0829427	total: 13m 15s	remaining: 13m 6s
# 503:	learn: 1.0823771	total: 13m 17s	remaining: 13m 4s
# 504:	learn: 1.0821118	total: 13m 18s	remaining: 13m 2s
# 505:	learn: 1.0815864	total: 13m 19s	remaining: 13m
# 506:	learn: 1.0813006	total: 13m 20s	remaining: 12m 58s
# 507:	learn: 1.0806950	total: 13m 22s	remaining: 12m 57s
# 508:	learn: 1.0803126	total: 13m 23s	remaining: 12m 55s
# 509:	learn: 1.0795846	total: 13m 25s	remaining: 12m 53s
# 510:	learn: 1.0790281	total: 13m 26s	remaining: 12m 51s
# 511:	learn: 1.0784551	total: 13m 27s	remaining: 12m 49s
# 512:	learn: 1.0781183	total: 13m 29s	remaining: 12m 48s
# 513:	learn: 1.0778779	total: 13m 30s	remaining: 12m 46s
# 514:	learn: 1.0776447	total: 13m 31s	remaining: 12m 44s
# 515:	learn: 1.0773888	total: 13m 33s	remaining: 12m 42s
# 516:	learn: 1.0770769	total: 13m 34s	remaining: 12m 40s
# 517:	learn: 1.0766122	total: 13m 35s	remaining: 12m 38s
# 518:	learn: 1.0762925	total: 13m 36s	remaining: 12m 36s
# 519:	learn: 1.0758252	total: 13m 37s	remaining: 12m 35s
# 520:	learn: 1.0756498	total: 13m 39s	remaining: 12m 33s
# 521:	learn: 1.0755061	total: 13m 40s	remaining: 12m 31s
# 522:	learn: 1.0750636	total: 13m 42s	remaining: 12m 29s
# 523:	learn: 1.0745690	total: 13m 43s	remaining: 12m 28s
# 524:	learn: 1.0742802	total: 13m 44s	remaining: 12m 26s
# 525:	learn: 1.0736860	total: 13m 46s	remaining: 12m 24s
# 526:	learn: 1.0733943	total: 13m 47s	remaining: 12m 22s
# 527:	learn: 1.0730086	total: 13m 48s	remaining: 12m 20s
# 528:	learn: 1.0722796	total: 13m 50s	remaining: 12m 19s
# 529:	learn: 1.0721151	total: 13m 52s	remaining: 12m 17s
# 530:	learn: 1.0716461	total: 13m 53s	remaining: 12m 16s
# 531:	learn: 1.0712585	total: 13m 55s	remaining: 12m 15s
# 532:	learn: 1.0707546	total: 13m 57s	remaining: 12m 13s
# 533:	learn: 1.0704607	total: 13m 58s	remaining: 12m 11s
# 534:	learn: 1.0700567	total: 13m 59s	remaining: 12m 10s
# 535:	learn: 1.0694763	total: 14m 1s	remaining: 12m 8s
# 536:	learn: 1.0689506	total: 14m 2s	remaining: 12m 6s
# 537:	learn: 1.0686340	total: 14m 4s	remaining: 12m 5s
# 538:	learn: 1.0682107	total: 14m 6s	remaining: 12m 3s
# 539:	learn: 1.0678577	total: 14m 7s	remaining: 12m 1s
# 540:	learn: 1.0675802	total: 14m 9s	remaining: 12m
# 541:	learn: 1.0669740	total: 14m 10s	remaining: 11m 58s
# 542:	learn: 1.0666649	total: 14m 12s	remaining: 11m 57s
# 543:	learn: 1.0663116	total: 14m 13s	remaining: 11m 55s
# 544:	learn: 1.0659689	total: 14m 14s	remaining: 11m 53s
# 545:	learn: 1.0654282	total: 14m 16s	remaining: 11m 51s
# 546:	learn: 1.0651359	total: 14m 17s	remaining: 11m 50s
# 547:	learn: 1.0649718	total: 14m 18s	remaining: 11m 48s
# 548:	learn: 1.0645632	total: 14m 20s	remaining: 11m 46s
# 549:	learn: 1.0641820	total: 14m 21s	remaining: 11m 44s
# 550:	learn: 1.0637636	total: 14m 22s	remaining: 11m 43s
# 551:	learn: 1.0634031	total: 14m 24s	remaining: 11m 41s
# 552:	learn: 1.0630705	total: 14m 25s	remaining: 11m 39s
# 553:	learn: 1.0626596	total: 14m 26s	remaining: 11m 37s
# 554:	learn: 1.0622058	total: 14m 28s	remaining: 11m 36s
# 555:	learn: 1.0619827	total: 14m 29s	remaining: 11m 34s
# 556:	learn: 1.0614633	total: 14m 30s	remaining: 11m 32s
# 557:	learn: 1.0610743	total: 14m 32s	remaining: 11m 31s
# 558:	learn: 1.0607448	total: 14m 34s	remaining: 11m 29s
# 559:	learn: 1.0603227	total: 14m 35s	remaining: 11m 28s
# 560:	learn: 1.0601104	total: 14m 37s	remaining: 11m 26s
# 561:	learn: 1.0598095	total: 14m 39s	remaining: 11m 25s
# 562:	learn: 1.0593415	total: 14m 40s	remaining: 11m 23s
# 563:	learn: 1.0591736	total: 14m 41s	remaining: 11m 21s
# 564:	learn: 1.0588809	total: 14m 42s	remaining: 11m 19s
# 565:	learn: 1.0583996	total: 14m 43s	remaining: 11m 17s
# 566:	learn: 1.0580188	total: 14m 44s	remaining: 11m 15s
# 567:	learn: 1.0577551	total: 14m 45s	remaining: 11m 13s
# 568:	learn: 1.0573202	total: 14m 46s	remaining: 11m 11s
# 569:	learn: 1.0568811	total: 14m 47s	remaining: 11m 9s
# 570:	learn: 1.0566806	total: 14m 48s	remaining: 11m 7s
# 571:	learn: 1.0561490	total: 14m 50s	remaining: 11m 5s
# 572:	learn: 1.0557528	total: 14m 51s	remaining: 11m 4s
# 573:	learn: 1.0551132	total: 14m 52s	remaining: 11m 2s
# 574:	learn: 1.0547816	total: 14m 53s	remaining: 11m
# 575:	learn: 1.0545804	total: 14m 54s	remaining: 10m 58s
# 576:	learn: 1.0542550	total: 14m 56s	remaining: 10m 57s
# 577:	learn: 1.0539209	total: 14m 57s	remaining: 10m 55s
# 578:	learn: 1.0532426	total: 14m 59s	remaining: 10m 53s
# 579:	learn: 1.0527892	total: 15m	remaining: 10m 52s
# 580:	learn: 1.0523551	total: 15m 2s	remaining: 10m 50s
# 581:	learn: 1.0520932	total: 15m 3s	remaining: 10m 48s
# 582:	learn: 1.0516003	total: 15m 4s	remaining: 10m 46s
# 583:	learn: 1.0510100	total: 15m 5s	remaining: 10m 44s
# 584:	learn: 1.0506258	total: 15m 6s	remaining: 10m 43s
# 585:	learn: 1.0502231	total: 15m 7s	remaining: 10m 41s
# 586:	learn: 1.0500271	total: 15m 8s	remaining: 10m 39s
# 587:	learn: 1.0494360	total: 15m 9s	remaining: 10m 37s
# 588:	learn: 1.0490087	total: 15m 11s	remaining: 10m 35s
# 589:	learn: 1.0487221	total: 15m 12s	remaining: 10m 34s
# 590:	learn: 1.0482745	total: 15m 14s	remaining: 10m 32s
# 591:	learn: 1.0479578	total: 15m 15s	remaining: 10m 31s
# 592:	learn: 1.0477210	total: 15m 16s	remaining: 10m 29s
# 593:	learn: 1.0473915	total: 15m 18s	remaining: 10m 27s
# 594:	learn: 1.0472735	total: 15m 19s	remaining: 10m 25s
# 595:	learn: 1.0469457	total: 15m 20s	remaining: 10m 24s
# 596:	learn: 1.0464655	total: 15m 22s	remaining: 10m 22s
# 597:	learn: 1.0462475	total: 15m 23s	remaining: 10m 20s
# 598:	learn: 1.0459322	total: 15m 25s	remaining: 10m 19s
# 599:	learn: 1.0456476	total: 15m 27s	remaining: 10m 18s
# 600:	learn: 1.0454131	total: 15m 29s	remaining: 10m 16s
# 601:	learn: 1.0450918	total: 15m 30s	remaining: 10m 15s
# 602:	learn: 1.0447931	total: 15m 32s	remaining: 10m 13s
# 603:	learn: 1.0446413	total: 15m 33s	remaining: 10m 12s
# 604:	learn: 1.0442215	total: 15m 35s	remaining: 10m 10s
# 605:	learn: 1.0438048	total: 15m 37s	remaining: 10m 9s
# 606:	learn: 1.0433598	total: 15m 39s	remaining: 10m 8s
# 607:	learn: 1.0427534	total: 15m 41s	remaining: 10m 6s
# 608:	learn: 1.0424961	total: 15m 42s	remaining: 10m 5s
# 609:	learn: 1.0421741	total: 15m 44s	remaining: 10m 3s
# 610:	learn: 1.0418053	total: 15m 46s	remaining: 10m 2s
# 611:	learn: 1.0414478	total: 15m 47s	remaining: 10m
# 612:	learn: 1.0411215	total: 15m 49s	remaining: 9m 59s
# 613:	learn: 1.0405320	total: 15m 51s	remaining: 9m 57s
# 614:	learn: 1.0400214	total: 15m 52s	remaining: 9m 56s
# 615:	learn: 1.0397841	total: 15m 54s	remaining: 9m 54s
# 616:	learn: 1.0392459	total: 15m 56s	remaining: 9m 53s
# 617:	learn: 1.0388865	total: 15m 58s	remaining: 9m 52s
# 618:	learn: 1.0385256	total: 16m	remaining: 9m 50s
# 619:	learn: 1.0381964	total: 16m 2s	remaining: 9m 49s
# 620:	learn: 1.0378376	total: 16m 3s	remaining: 9m 48s
# 621:	learn: 1.0375375	total: 16m 5s	remaining: 9m 46s
# 622:	learn: 1.0372280	total: 16m 7s	remaining: 9m 45s
# 623:	learn: 1.0368295	total: 16m 8s	remaining: 9m 43s
# 624:	learn: 1.0363999	total: 16m 9s	remaining: 9m 41s
# 625:	learn: 1.0361097	total: 16m 11s	remaining: 9m 40s
# 626:	learn: 1.0356789	total: 16m 13s	remaining: 9m 38s
# 627:	learn: 1.0355590	total: 16m 14s	remaining: 9m 37s
# 628:	learn: 1.0352948	total: 16m 16s	remaining: 9m 35s
# 629:	learn: 1.0345125	total: 16m 18s	remaining: 9m 34s
# 630:	learn: 1.0343822	total: 16m 19s	remaining: 9m 32s
# 631:	learn: 1.0340237	total: 16m 20s	remaining: 9m 31s
# 632:	learn: 1.0337721	total: 16m 21s	remaining: 9m 29s
# 633:	learn: 1.0334834	total: 16m 24s	remaining: 9m 28s
# 634:	learn: 1.0333165	total: 16m 25s	remaining: 9m 26s
# 635:	learn: 1.0330783	total: 16m 26s	remaining: 9m 24s
# 636:	learn: 1.0329197	total: 16m 27s	remaining: 9m 22s
# 637:	learn: 1.0327112	total: 16m 29s	remaining: 9m 21s
# 638:	learn: 1.0324688	total: 16m 30s	remaining: 9m 19s
# 639:	learn: 1.0318650	total: 16m 31s	remaining: 9m 17s
# 640:	learn: 1.0315490	total: 16m 32s	remaining: 9m 15s
# 641:	learn: 1.0311877	total: 16m 33s	remaining: 9m 14s
# 642:	learn: 1.0308970	total: 16m 34s	remaining: 9m 12s
# 643:	learn: 1.0304342	total: 16m 36s	remaining: 9m 10s
# 644:	learn: 1.0300601	total: 16m 38s	remaining: 9m 9s
# 645:	learn: 1.0298003	total: 16m 39s	remaining: 9m 7s
# 646:	learn: 1.0296406	total: 16m 41s	remaining: 9m 6s
# 647:	learn: 1.0294489	total: 16m 43s	remaining: 9m 4s
# 648:	learn: 1.0292764	total: 16m 45s	remaining: 9m 3s
# 649:	learn: 1.0288217	total: 16m 46s	remaining: 9m 2s
# 650:	learn: 1.0286715	total: 16m 49s	remaining: 9m
# 651:	learn: 1.0279376	total: 16m 51s	remaining: 8m 59s
# 652:	learn: 1.0275826	total: 16m 52s	remaining: 8m 58s
# 653:	learn: 1.0271623	total: 16m 54s	remaining: 8m 56s
# 654:	learn: 1.0270235	total: 16m 55s	remaining: 8m 55s
# 655:	learn: 1.0267450	total: 16m 57s	remaining: 8m 53s
# 656:	learn: 1.0264058	total: 16m 58s	remaining: 8m 51s
# 657:	learn: 1.0260228	total: 16m 59s	remaining: 8m 50s
# 658:	learn: 1.0258560	total: 17m 1s	remaining: 8m 48s
# 659:	learn: 1.0255289	total: 17m 3s	remaining: 8m 47s
# 660:	learn: 1.0251898	total: 17m 4s	remaining: 8m 45s
# 661:	learn: 1.0249285	total: 17m 5s	remaining: 8m 43s
# 662:	learn: 1.0247364	total: 17m 6s	remaining: 8m 41s
# 663:	learn: 1.0244255	total: 17m 8s	remaining: 8m 40s
# 664:	learn: 1.0241931	total: 17m 9s	remaining: 8m 38s
# 665:	learn: 1.0238414	total: 17m 10s	remaining: 8m 36s
# 666:	learn: 1.0231404	total: 17m 11s	remaining: 8m 35s
# 667:	learn: 1.0227979	total: 17m 12s	remaining: 8m 33s
# 668:	learn: 1.0224520	total: 17m 13s	remaining: 8m 31s
# 669:	learn: 1.0222378	total: 17m 15s	remaining: 8m 29s
# 670:	learn: 1.0217434	total: 17m 16s	remaining: 8m 28s
# 671:	learn: 1.0213822	total: 17m 17s	remaining: 8m 26s
# 672:	learn: 1.0210929	total: 17m 18s	remaining: 8m 24s
# 673:	learn: 1.0209365	total: 17m 19s	remaining: 8m 22s
# 674:	learn: 1.0207314	total: 17m 20s	remaining: 8m 21s
# 675:	learn: 1.0204371	total: 17m 21s	remaining: 8m 19s
# 676:	learn: 1.0201571	total: 17m 22s	remaining: 8m 17s
# 677:	learn: 1.0199472	total: 17m 24s	remaining: 8m 15s
# 678:	learn: 1.0195446	total: 17m 25s	remaining: 8m 14s
# 679:	learn: 1.0192516	total: 17m 26s	remaining: 8m 12s
# 680:	learn: 1.0191076	total: 17m 28s	remaining: 8m 10s
# 681:	learn: 1.0188391	total: 17m 30s	remaining: 8m 9s
# 682:	learn: 1.0186520	total: 17m 31s	remaining: 8m 8s
# 683:	learn: 1.0184805	total: 17m 33s	remaining: 8m 6s
# 684:	learn: 1.0182627	total: 17m 34s	remaining: 8m 5s
# 685:	learn: 1.0177231	total: 17m 36s	remaining: 8m 3s
# 686:	learn: 1.0175185	total: 17m 37s	remaining: 8m 2s
# 687:	learn: 1.0173716	total: 17m 39s	remaining: 8m
# 688:	learn: 1.0170107	total: 17m 41s	remaining: 7m 59s
# 689:	learn: 1.0167147	total: 17m 43s	remaining: 7m 57s
# 690:	learn: 1.0165570	total: 17m 45s	remaining: 7m 56s
# 691:	learn: 1.0162692	total: 17m 46s	remaining: 7m 54s
# 692:	learn: 1.0160019	total: 17m 48s	remaining: 7m 53s
# 693:	learn: 1.0157938	total: 17m 50s	remaining: 7m 51s
# 694:	learn: 1.0155541	total: 17m 52s	remaining: 7m 50s
# 695:	learn: 1.0152453	total: 17m 53s	remaining: 7m 48s
# 696:	learn: 1.0148834	total: 17m 55s	remaining: 7m 47s
# 697:	learn: 1.0147128	total: 17m 56s	remaining: 7m 45s
# 698:	learn: 1.0144310	total: 17m 57s	remaining: 7m 44s
# 699:	learn: 1.0142356	total: 17m 59s	remaining: 7m 42s
# 700:	learn: 1.0138977	total: 18m	remaining: 7m 40s
# 701:	learn: 1.0136635	total: 18m 1s	remaining: 7m 39s
# 702:	learn: 1.0134138	total: 18m 3s	remaining: 7m 37s
# 703:	learn: 1.0132644	total: 18m 4s	remaining: 7m 36s
# 704:	learn: 1.0130676	total: 18m 5s	remaining: 7m 34s
# 705:	learn: 1.0125626	total: 18m 7s	remaining: 7m 32s
# 706:	learn: 1.0122178	total: 18m 8s	remaining: 7m 31s
# 707:	learn: 1.0119417	total: 18m 9s	remaining: 7m 29s
# 708:	learn: 1.0117995	total: 18m 11s	remaining: 7m 27s
# 709:	learn: 1.0114238	total: 18m 12s	remaining: 7m 26s
# 710:	learn: 1.0112152	total: 18m 13s	remaining: 7m 24s
# 711:	learn: 1.0108988	total: 18m 15s	remaining: 7m 23s
# 712:	learn: 1.0105064	total: 18m 16s	remaining: 7m 21s
# 713:	learn: 1.0098855	total: 18m 18s	remaining: 7m 19s
# 714:	learn: 1.0095619	total: 18m 19s	remaining: 7m 18s
# 715:	learn: 1.0090748	total: 18m 21s	remaining: 7m 16s
# 716:	learn: 1.0089190	total: 18m 22s	remaining: 7m 15s
# 717:	learn: 1.0084957	total: 18m 24s	remaining: 7m 13s
# 718:	learn: 1.0080907	total: 18m 25s	remaining: 7m 11s
# 719:	learn: 1.0078466	total: 18m 26s	remaining: 7m 10s
# 720:	learn: 1.0075778	total: 18m 27s	remaining: 7m 8s
# 721:	learn: 1.0073913	total: 18m 29s	remaining: 7m 7s
# 722:	learn: 1.0071229	total: 18m 30s	remaining: 7m 5s
# 723:	learn: 1.0068779	total: 18m 31s	remaining: 7m 3s
# 724:	learn: 1.0066799	total: 18m 32s	remaining: 7m 2s
# 725:	learn: 1.0065544	total: 18m 34s	remaining: 7m
# 726:	learn: 1.0059341	total: 18m 35s	remaining: 6m 58s
# 727:	learn: 1.0056080	total: 18m 36s	remaining: 6m 57s
# 728:	learn: 1.0053788	total: 18m 38s	remaining: 6m 55s
# 729:	learn: 1.0050781	total: 18m 39s	remaining: 6m 54s
# 730:	learn: 1.0047633	total: 18m 41s	remaining: 6m 52s
# 731:	learn: 1.0043910	total: 18m 42s	remaining: 6m 50s
# 732:	learn: 1.0042035	total: 18m 43s	remaining: 6m 49s
# 733:	learn: 1.0038179	total: 18m 45s	remaining: 6m 47s
# 734:	learn: 1.0035515	total: 18m 46s	remaining: 6m 46s
# 735:	learn: 1.0032752	total: 18m 47s	remaining: 6m 44s
# 736:	learn: 1.0029170	total: 18m 49s	remaining: 6m 43s
# 737:	learn: 1.0025859	total: 18m 50s	remaining: 6m 41s
# 738:	learn: 1.0023170	total: 18m 52s	remaining: 6m 39s
# 739:	learn: 1.0019623	total: 18m 53s	remaining: 6m 38s
# 740:	learn: 1.0017969	total: 18m 55s	remaining: 6m 36s
# 741:	learn: 1.0013869	total: 18m 57s	remaining: 6m 35s
# 742:	learn: 1.0011222	total: 18m 58s	remaining: 6m 33s
# 743:	learn: 1.0006615	total: 18m 59s	remaining: 6m 32s
# 744:	learn: 1.0005485	total: 19m	remaining: 6m 30s
# 745:	learn: 0.9998847	total: 19m 2s	remaining: 6m 28s
# 746:	learn: 0.9996598	total: 19m 3s	remaining: 6m 27s
# 747:	learn: 0.9993657	total: 19m 4s	remaining: 6m 25s
# 748:	learn: 0.9990109	total: 19m 6s	remaining: 6m 24s
# 749:	learn: 0.9987139	total: 19m 7s	remaining: 6m 22s
# 750:	learn: 0.9985190	total: 19m 8s	remaining: 6m 20s
# 751:	learn: 0.9982445	total: 19m 10s	remaining: 6m 19s
# 752:	learn: 0.9979476	total: 19m 11s	remaining: 6m 17s
# 753:	learn: 0.9977400	total: 19m 12s	remaining: 6m 16s
# 754:	learn: 0.9974319	total: 19m 14s	remaining: 6m 14s
# 755:	learn: 0.9971227	total: 19m 15s	remaining: 6m 12s
# 756:	learn: 0.9967307	total: 19m 16s	remaining: 6m 11s
# 757:	learn: 0.9965690	total: 19m 17s	remaining: 6m 9s
# 758:	learn: 0.9964901	total: 19m 18s	remaining: 6m 7s
# 759:	learn: 0.9963586	total: 19m 20s	remaining: 6m 6s
# 760:	learn: 0.9956220	total: 19m 21s	remaining: 6m 4s
# 761:	learn: 0.9954566	total: 19m 22s	remaining: 6m 3s
# 762:	learn: 0.9951119	total: 19m 23s	remaining: 6m 1s
# 763:	learn: 0.9950086	total: 19m 25s	remaining: 5m 59s
# 764:	learn: 0.9948270	total: 19m 26s	remaining: 5m 58s
# 765:	learn: 0.9945011	total: 19m 27s	remaining: 5m 56s
# 766:	learn: 0.9943329	total: 19m 29s	remaining: 5m 55s
# 767:	learn: 0.9942259	total: 19m 30s	remaining: 5m 53s
# 768:	learn: 0.9939594	total: 19m 31s	remaining: 5m 51s
# 769:	learn: 0.9937927	total: 19m 32s	remaining: 5m 50s
# 770:	learn: 0.9936088	total: 19m 34s	remaining: 5m 48s
# 771:	learn: 0.9932396	total: 19m 35s	remaining: 5m 47s
# 772:	learn: 0.9928414	total: 19m 37s	remaining: 5m 45s
# 773:	learn: 0.9926706	total: 19m 38s	remaining: 5m 44s
# 774:	learn: 0.9924642	total: 19m 39s	remaining: 5m 42s
# 775:	learn: 0.9922753	total: 19m 41s	remaining: 5m 40s
# 776:	learn: 0.9919189	total: 19m 42s	remaining: 5m 39s
# 777:	learn: 0.9915674	total: 19m 44s	remaining: 5m 37s
# 778:	learn: 0.9911108	total: 19m 45s	remaining: 5m 36s
# 779:	learn: 0.9909712	total: 19m 46s	remaining: 5m 34s
# 780:	learn: 0.9905877	total: 19m 48s	remaining: 5m 33s
# 781:	learn: 0.9903601	total: 19m 49s	remaining: 5m 31s
# 782:	learn: 0.9901587	total: 19m 50s	remaining: 5m 30s
# 783:	learn: 0.9899690	total: 19m 52s	remaining: 5m 28s
# 784:	learn: 0.9898073	total: 19m 53s	remaining: 5m 26s
# 785:	learn: 0.9896272	total: 19m 54s	remaining: 5m 25s
# 786:	learn: 0.9893671	total: 19m 56s	remaining: 5m 23s
# 787:	learn: 0.9891819	total: 19m 57s	remaining: 5m 22s
# 788:	learn: 0.9889005	total: 19m 58s	remaining: 5m 20s
# 789:	learn: 0.9885691	total: 20m	remaining: 5m 19s
# 790:	learn: 0.9882360	total: 20m 1s	remaining: 5m 17s
# 791:	learn: 0.9880340	total: 20m 3s	remaining: 5m 16s
# 792:	learn: 0.9879153	total: 20m 4s	remaining: 5m 14s
# 793:	learn: 0.9876531	total: 20m 5s	remaining: 5m 12s
# 794:	learn: 0.9873519	total: 20m 7s	remaining: 5m 11s
# 795:	learn: 0.9871191	total: 20m 9s	remaining: 5m 9s
# 796:	learn: 0.9869035	total: 20m 10s	remaining: 5m 8s
# 797:	learn: 0.9866783	total: 20m 11s	remaining: 5m 6s
# 798:	learn: 0.9865054	total: 20m 12s	remaining: 5m 5s
# 799:	learn: 0.9863433	total: 20m 14s	remaining: 5m 3s
# 800:	learn: 0.9861830	total: 20m 16s	remaining: 5m 2s
# 801:	learn: 0.9856038	total: 20m 17s	remaining: 5m
# 802:	learn: 0.9853419	total: 20m 19s	remaining: 4m 59s
# 803:	learn: 0.9851301	total: 20m 20s	remaining: 4m 57s
# 804:	learn: 0.9848538	total: 20m 21s	remaining: 4m 55s
# 805:	learn: 0.9847198	total: 20m 23s	remaining: 4m 54s
# 806:	learn: 0.9845655	total: 20m 24s	remaining: 4m 52s
# 807:	learn: 0.9841655	total: 20m 26s	remaining: 4m 51s
# 808:	learn: 0.9838917	total: 20m 27s	remaining: 4m 49s
# 809:	learn: 0.9837043	total: 20m 29s	remaining: 4m 48s
# 810:	learn: 0.9835570	total: 20m 30s	remaining: 4m 46s
# 811:	learn: 0.9833344	total: 20m 32s	remaining: 4m 45s
# 812:	learn: 0.9832231	total: 20m 33s	remaining: 4m 43s
# 813:	learn: 0.9828805	total: 20m 34s	remaining: 4m 42s
# 814:	learn: 0.9827099	total: 20m 35s	remaining: 4m 40s
# 815:	learn: 0.9824244	total: 20m 37s	remaining: 4m 38s
# 816:	learn: 0.9821815	total: 20m 38s	remaining: 4m 37s
# 817:	learn: 0.9819369	total: 20m 40s	remaining: 4m 35s
# 818:	learn: 0.9816673	total: 20m 41s	remaining: 4m 34s
# 819:	learn: 0.9815655	total: 20m 43s	remaining: 4m 32s
# 820:	learn: 0.9812403	total: 20m 44s	remaining: 4m 31s
# 821:	learn: 0.9810497	total: 20m 46s	remaining: 4m 29s
# 822:	learn: 0.9808295	total: 20m 47s	remaining: 4m 28s
# 823:	learn: 0.9804546	total: 20m 48s	remaining: 4m 26s
# 824:	learn: 0.9801046	total: 20m 50s	remaining: 4m 25s
# 825:	learn: 0.9798985	total: 20m 51s	remaining: 4m 23s
# 826:	learn: 0.9797894	total: 20m 52s	remaining: 4m 22s
# 827:	learn: 0.9795950	total: 20m 53s	remaining: 4m 20s
# 828:	learn: 0.9793763	total: 20m 55s	remaining: 4m 18s
# 829:	learn: 0.9791261	total: 20m 56s	remaining: 4m 17s
# 830:	learn: 0.9787435	total: 20m 57s	remaining: 4m 15s
# 831:	learn: 0.9784673	total: 20m 58s	remaining: 4m 14s
# 832:	learn: 0.9782925	total: 21m	remaining: 4m 12s
# 833:	learn: 0.9780310	total: 21m 1s	remaining: 4m 11s
# 834:	learn: 0.9778159	total: 21m 2s	remaining: 4m 9s
# 835:	learn: 0.9777090	total: 21m 3s	remaining: 4m 7s
# 836:	learn: 0.9774869	total: 21m 4s	remaining: 4m 6s
# 837:	learn: 0.9772521	total: 21m 5s	remaining: 4m 4s
# 838:	learn: 0.9771026	total: 21m 6s	remaining: 4m 3s
# 839:	learn: 0.9769425	total: 21m 8s	remaining: 4m 1s
# 840:	learn: 0.9767557	total: 21m 9s	remaining: 3m 59s
# 841:	learn: 0.9763430	total: 21m 10s	remaining: 3m 58s
# 842:	learn: 0.9758009	total: 21m 11s	remaining: 3m 56s
# 843:	learn: 0.9756243	total: 21m 12s	remaining: 3m 55s
# 844:	learn: 0.9754664	total: 21m 13s	remaining: 3m 53s
# 845:	learn: 0.9752780	total: 21m 15s	remaining: 3m 52s
# 846:	learn: 0.9749523	total: 21m 16s	remaining: 3m 50s
# 847:	learn: 0.9747486	total: 21m 17s	remaining: 3m 48s
# 848:	learn: 0.9744924	total: 21m 18s	remaining: 3m 47s
# 849:	learn: 0.9743220	total: 21m 19s	remaining: 3m 45s
# 850:	learn: 0.9739362	total: 21m 21s	remaining: 3m 44s
# 851:	learn: 0.9737056	total: 21m 22s	remaining: 3m 42s
# 852:	learn: 0.9734583	total: 21m 23s	remaining: 3m 41s
# 853:	learn: 0.9730715	total: 21m 24s	remaining: 3m 39s
# 854:	learn: 0.9728602	total: 21m 25s	remaining: 3m 38s
# 855:	learn: 0.9726803	total: 21m 26s	remaining: 3m 36s
# 856:	learn: 0.9723763	total: 21m 28s	remaining: 3m 34s
# 857:	learn: 0.9721394	total: 21m 29s	remaining: 3m 33s
# 858:	learn: 0.9718898	total: 21m 30s	remaining: 3m 31s
# 859:	learn: 0.9716805	total: 21m 31s	remaining: 3m 30s
# 860:	learn: 0.9714742	total: 21m 32s	remaining: 3m 28s
# 861:	learn: 0.9712852	total: 21m 33s	remaining: 3m 27s
# 862:	learn: 0.9712070	total: 21m 34s	remaining: 3m 25s
# 863:	learn: 0.9710144	total: 21m 35s	remaining: 3m 23s
# 864:	learn: 0.9707896	total: 21m 36s	remaining: 3m 22s
# 865:	learn: 0.9706954	total: 21m 38s	remaining: 3m 20s
# 866:	learn: 0.9703859	total: 21m 40s	remaining: 3m 19s
# 867:	learn: 0.9700966	total: 21m 41s	remaining: 3m 17s
# 868:	learn: 0.9698721	total: 21m 43s	remaining: 3m 16s
# 869:	learn: 0.9697145	total: 21m 44s	remaining: 3m 14s
# 870:	learn: 0.9695615	total: 21m 46s	remaining: 3m 13s
# 871:	learn: 0.9693179	total: 21m 47s	remaining: 3m 12s
# 872:	learn: 0.9691413	total: 21m 49s	remaining: 3m 10s
# 873:	learn: 0.9688645	total: 21m 50s	remaining: 3m 8s
# 874:	learn: 0.9687570	total: 21m 51s	remaining: 3m 7s
# 875:	learn: 0.9685707	total: 21m 53s	remaining: 3m 5s
# 876:	learn: 0.9682569	total: 21m 54s	remaining: 3m 4s
# 877:	learn: 0.9681161	total: 21m 55s	remaining: 3m 2s
# 878:	learn: 0.9678782	total: 21m 57s	remaining: 3m 1s
# 879:	learn: 0.9676776	total: 21m 59s	remaining: 2m 59s
# 880:	learn: 0.9674484	total: 22m	remaining: 2m 58s
# 881:	learn: 0.9672948	total: 22m 2s	remaining: 2m 56s
# 882:	learn: 0.9670833	total: 22m 3s	remaining: 2m 55s
# 883:	learn: 0.9667981	total: 22m 5s	remaining: 2m 53s
# 884:	learn: 0.9666074	total: 22m 6s	remaining: 2m 52s
# 885:	learn: 0.9663259	total: 22m 8s	remaining: 2m 50s
# 886:	learn: 0.9661748	total: 22m 9s	remaining: 2m 49s
# 887:	learn: 0.9659609	total: 22m 10s	remaining: 2m 47s
# 888:	learn: 0.9656720	total: 22m 12s	remaining: 2m 46s
# 889:	learn: 0.9655318	total: 22m 13s	remaining: 2m 44s
# 890:	learn: 0.9652320	total: 22m 15s	remaining: 2m 43s
# 891:	learn: 0.9650564	total: 22m 16s	remaining: 2m 41s
# 892:	learn: 0.9648799	total: 22m 17s	remaining: 2m 40s
# 893:	learn: 0.9647211	total: 22m 19s	remaining: 2m 38s
# 894:	learn: 0.9644520	total: 22m 21s	remaining: 2m 37s
# 895:	learn: 0.9643424	total: 22m 22s	remaining: 2m 35s
# 896:	learn: 0.9641027	total: 22m 23s	remaining: 2m 34s
# 897:	learn: 0.9639182	total: 22m 25s	remaining: 2m 32s
# 898:	learn: 0.9638565	total: 22m 26s	remaining: 2m 31s
# 899:	learn: 0.9633619	total: 22m 28s	remaining: 2m 29s
# 900:	learn: 0.9631173	total: 22m 29s	remaining: 2m 28s
# 901:	learn: 0.9628704	total: 22m 30s	remaining: 2m 26s
# 902:	learn: 0.9626470	total: 22m 32s	remaining: 2m 25s
# 903:	learn: 0.9623994	total: 22m 33s	remaining: 2m 23s
# 904:	learn: 0.9622773	total: 22m 35s	remaining: 2m 22s
# 905:	learn: 0.9620398	total: 22m 36s	remaining: 2m 20s
# 906:	learn: 0.9618770	total: 22m 37s	remaining: 2m 19s
# 907:	learn: 0.9617612	total: 22m 39s	remaining: 2m 17s
# 908:	learn: 0.9614424	total: 22m 40s	remaining: 2m 16s
# 909:	learn: 0.9608689	total: 22m 42s	remaining: 2m 14s
# 910:	learn: 0.9605880	total: 22m 43s	remaining: 2m 13s
# 911:	learn: 0.9604559	total: 22m 44s	remaining: 2m 11s
# 912:	learn: 0.9601701	total: 22m 46s	remaining: 2m 10s
# 913:	learn: 0.9600304	total: 22m 47s	remaining: 2m 8s
# 914:	learn: 0.9598878	total: 22m 48s	remaining: 2m 7s
# 915:	learn: 0.9596369	total: 22m 50s	remaining: 2m 5s
# 916:	learn: 0.9595010	total: 22m 51s	remaining: 2m 4s
# 917:	learn: 0.9593485	total: 22m 53s	remaining: 2m 2s
# 918:	learn: 0.9592260	total: 22m 54s	remaining: 2m 1s
# 919:	learn: 0.9590489	total: 22m 55s	remaining: 1m 59s
# 920:	learn: 0.9588752	total: 22m 57s	remaining: 1m 58s
# 921:	learn: 0.9586631	total: 22m 58s	remaining: 1m 56s
# 922:	learn: 0.9585585	total: 22m 59s	remaining: 1m 55s
# 923:	learn: 0.9584143	total: 23m 1s	remaining: 1m 53s
# 924:	learn: 0.9582166	total: 23m 2s	remaining: 1m 52s
# 925:	learn: 0.9581328	total: 23m 4s	remaining: 1m 50s
# 926:	learn: 0.9579772	total: 23m 5s	remaining: 1m 49s
# 927:	learn: 0.9578405	total: 23m 6s	remaining: 1m 47s
# 928:	learn: 0.9573215	total: 23m 7s	remaining: 1m 46s
# 929:	learn: 0.9570126	total: 23m 9s	remaining: 1m 44s
# 930:	learn: 0.9567688	total: 23m 10s	remaining: 1m 43s
# 931:	learn: 0.9565478	total: 23m 11s	remaining: 1m 41s
# 932:	learn: 0.9563280	total: 23m 12s	remaining: 1m 40s
# 933:	learn: 0.9559178	total: 23m 14s	remaining: 1m 38s
# 934:	learn: 0.9556837	total: 23m 15s	remaining: 1m 37s
# 935:	learn: 0.9554708	total: 23m 17s	remaining: 1m 35s
# 936:	learn: 0.9553395	total: 23m 18s	remaining: 1m 34s
# 937:	learn: 0.9550117	total: 23m 19s	remaining: 1m 32s
# 938:	learn: 0.9549243	total: 23m 21s	remaining: 1m 31s
# 939:	learn: 0.9546987	total: 23m 23s	remaining: 1m 29s
# 940:	learn: 0.9542181	total: 23m 25s	remaining: 1m 28s
# 941:	learn: 0.9540683	total: 23m 26s	remaining: 1m 26s
# 942:	learn: 0.9538405	total: 23m 28s	remaining: 1m 25s
# 943:	learn: 0.9537526	total: 23m 30s	remaining: 1m 23s
# 944:	learn: 0.9536290	total: 23m 31s	remaining: 1m 22s
# 945:	learn: 0.9534605	total: 23m 32s	remaining: 1m 20s
# 946:	learn: 0.9532902	total: 23m 33s	remaining: 1m 19s
# 947:	learn: 0.9531241	total: 23m 34s	remaining: 1m 17s
# 948:	learn: 0.9530325	total: 23m 35s	remaining: 1m 16s
# 949:	learn: 0.9528558	total: 23m 36s	remaining: 1m 14s
# 950:	learn: 0.9526802	total: 23m 37s	remaining: 1m 13s
# 951:	learn: 0.9524407	total: 23m 38s	remaining: 1m 11s
# 952:	learn: 0.9522170	total: 23m 39s	remaining: 1m 10s
# 953:	learn: 0.9519940	total: 23m 40s	remaining: 1m 8s
# 954:	learn: 0.9518734	total: 23m 41s	remaining: 1m 6s
# 955:	learn: 0.9515790	total: 23m 43s	remaining: 1m 5s
# 956:	learn: 0.9513782	total: 23m 44s	remaining: 1m 3s
# 957:	learn: 0.9512272	total: 23m 45s	remaining: 1m 2s
# 958:	learn: 0.9509662	total: 23m 46s	remaining: 1m 1s
# 959:	learn: 0.9507546	total: 23m 47s	remaining: 59.5s
# 960:	learn: 0.9505683	total: 23m 49s	remaining: 58s
# 961:	learn: 0.9503170	total: 23m 50s	remaining: 56.5s
# 962:	learn: 0.9498557	total: 23m 51s	remaining: 55s
# 963:	learn: 0.9497087	total: 23m 52s	remaining: 53.5s
# 964:	learn: 0.9495489	total: 23m 54s	remaining: 52s
# 965:	learn: 0.9493799	total: 23m 55s	remaining: 50.5s
# 966:	learn: 0.9492029	total: 23m 56s	remaining: 49s
# 967:	learn: 0.9489640	total: 23m 57s	remaining: 47.5s
# 968:	learn: 0.9487219	total: 23m 59s	remaining: 46s
# 969:	learn: 0.9485639	total: 24m	remaining: 44.5s
# 970:	learn: 0.9483990	total: 24m 1s	remaining: 43.1s
# 971:	learn: 0.9482375	total: 24m 2s	remaining: 41.6s
# 972:	learn: 0.9479351	total: 24m 3s	remaining: 40.1s
# 973:	learn: 0.9477356	total: 24m 5s	remaining: 38.6s
# 974:	learn: 0.9475756	total: 24m 6s	remaining: 37.1s
# 975:	learn: 0.9474352	total: 24m 8s	remaining: 35.6s
# 976:	learn: 0.9471895	total: 24m 10s	remaining: 34.1s
# 977:	learn: 0.9470490	total: 24m 11s	remaining: 32.7s
# 978:	learn: 0.9468210	total: 24m 12s	remaining: 31.2s
# 979:	learn: 0.9466411	total: 24m 15s	remaining: 29.7s
# 980:	learn: 0.9463490	total: 24m 16s	remaining: 28.2s
# 981:	learn: 0.9461733	total: 24m 18s	remaining: 26.7s
# 982:	learn: 0.9460182	total: 24m 19s	remaining: 25.2s
# 983:	learn: 0.9457169	total: 24m 21s	remaining: 23.8s
# 984:	learn: 0.9456295	total: 24m 23s	remaining: 22.3s
# 985:	learn: 0.9455284	total: 24m 24s	remaining: 20.8s
# 986:	learn: 0.9454512	total: 24m 26s	remaining: 19.3s
# 987:	learn: 0.9450177	total: 24m 27s	remaining: 17.8s
# 988:	learn: 0.9448260	total: 24m 29s	remaining: 16.3s
# 989:	learn: 0.9447005	total: 24m 30s	remaining: 14.9s
# 990:	learn: 0.9445209	total: 24m 32s	remaining: 13.4s
# 991:	learn: 0.9444062	total: 24m 34s	remaining: 11.9s
# 992:	learn: 0.9442064	total: 24m 36s	remaining: 10.4s
# 993:	learn: 0.9439366	total: 24m 38s	remaining: 8.92s
# 994:	learn: 0.9437708	total: 24m 39s	remaining: 7.44s
# 995:	learn: 0.9435692	total: 24m 41s	remaining: 5.95s
# 996:	learn: 0.9434365	total: 24m 43s	remaining: 4.46s
# 997:	learn: 0.9432859	total: 24m 45s	remaining: 2.98s
# 998:	learn: 0.9430830	total: 24m 47s	remaining: 1.49s
# 999:	learn: 0.9428319	total: 24m 48s	remaining: 0us

# %%
acc_catboost
# Out:
# 98.65

# %% [markdown]
# # LightGbm

# %%
from lightgbm import LGBMRegressor
lgb = LGBMRegressor()
lgb.fit(X_train, Y_train)
Y_pred = lgb.predict(X_test_scaled)
acc_lgb = round(lgb.score(X_train, Y_train) * 100, 2)
acc_lgb
# Out:
# 97.19

# %% [markdown]
# # XG Boost

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(X_train_scaled,Y_train)
Y_pred = xgb.predict(X_test_scaled)
acc_xgb = round(xgb.score(X_train_scaled,Y_train)*100,2)
acc_xgb
# Out:
# 97.84

# %% [markdown]
# # Neural Networks

# %%
import tensorflow as tf 
from tensorflow import keras

# %%
#syntax =  keras.layers.Dense(output_dimension, input_shape, activation)

model = keras.Sequential([
  
    keras.layers.Dense(128, input_shape=(25,), activation='relu'),#Dense means all the neurons of present are connected to all the neurons in next layer
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1)
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='mean_squared_error', 
              metrics=['mae','mse'])

model.fit(X_train_scaled, Y_train, epochs=10)#start slow with epochs and then increase the value
# Out:
# Epoch 1/10
# 188625/188625 [==============================] - 267s 1ms/step - loss: 2.6877 - mae: 0.8394 - mse: 2.6877
# Epoch 2/10
# 188625/188625 [==============================] - 264s 1ms/step - loss: 1.3195 - mae: 0.6266 - mse: 1.3195
# Epoch 3/10
# 188625/188625 [==============================] - 265s 1ms/step - loss: 1.1070 - mae: 0.5834 - mse: 1.1070
# Epoch 4/10
# 188625/188625 [==============================] - 266s 1ms/step - loss: 1.0042 - mae: 0.5617 - mse: 1.0042
# Epoch 5/10
# 188625/188625 [==============================] - 262s 1ms/step - loss: 0.9457 - mae: 0.5489 - mse: 0.9457 2s - l
# Epoch 6/10
# 188625/188625 [==============================] - 247s 1ms/step - loss: 0.8982 - mae: 0.5391 - mse: 0.8982
# Epoch 7/10
# 188625/188625 [==============================] - 242s 1ms/step - loss: 0.8651 - mae: 0.5319 - mse: 0.8651
# Epoch 8/10
# 188625/188625 [==============================] - 250s 1ms/step - loss: 0.8403 - mae: 0.5266 - mse: 0.8403 2s - loss: 0.8407 - mae: 0.5267 - mse:  - ETA: 2s - loss: 0.8406 - mae: 0.5267 - E
# Epoch 9/10
# 188625/188625 [==============================] - 255s 1ms/step - loss: 0.8142 - mae: 0.5210 - mse: 0.8142
# Epoch 10/10
# 188625/188625 [==============================] - 255s 1ms/step - loss: 0.7979 - mae: 0.5171 - mse: 0.7979

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               3328
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 15)                1935
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 21,791
# Trainable params: 21,791
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate(X_test_scaled)
# Out:
# 125750/125750 [==============================] - 86s 686us/step - loss: 0.0000e+00 - mae: 0.0000e+00 - mse: 0.0000e+001s - loss: 0.0000e
# [0.0, 0.0, 0.0]

# %%
model.evaluate_generator(X_test_scaled)
# Out:
# [0.0, 0.0, 0.0]

# %%
pred = model.predict(X_test_scaled)

# %%
pred
# Out:
# array([[6.4515696],
#        [5.5990343],
#        [6.8677263],
#        ...,
#        [6.4515696],
#        [6.4515696],
#        [6.4515696]], dtype=float32)

# %%
pred = np.argmax(pred,axis = 1)

# %%
pred = pd.Series(pred,name="pressure")

# %%
submission = pd.concat([pd.Series(range(1,4024000),name = "id"),pred],axis = 1)

# %%
submission['id']=submission['id'].astype('Int32')
submission.head()
# Out:
#    id  pressure
# 0   1         0
# 1   2         0
# 2   3         0
# 3   4         0
# 4   5         0

# %%
submission.to_csv("Submission.csv",index=False)
